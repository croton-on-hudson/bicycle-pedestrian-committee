# %% [markdown]
# ## Import data from CSV data file
# The CSV file has been exported from Google Sheets survey responses.

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('responses.csv', index_col=None, parse_dates=['Timestamp'])

# %% [markdown]
# ## Clean up column names
# The original column names are the questions.... let's simplifies them.  And while we're at it, set appropriate columns as categorical data to speed up analysis.

# %%
# replace long column titles with shorter versions
df.columns = [ 'date', 'neighborhood', 'demographic', 'schools', 'child_bus_freq', 'child_bike_freq', 'child_driven_freq', 'child_drive_freq', 'child_walk_freq', 'child_drive_reason', 'child_no_walk_reason', 'child_no_bike_reason', 'walk_freq', 'bike_freq', 'bikes_on_sidewalk', 'self_jog_frequency', 'commutes', 'child_self_school', 'child_self_bus_freq', 'child_self_bike_freq', 'child_self_driven_freq', 'child_self_drive_freq', 'child_self_walk_freq', 'child_self_commutes', 'child_self_has_children', 'commuter_distance', 'commuter_type', 'commuter_walk_to_station_freq', 'commuter_bike_to_station_freq', 'commuter_drive_to_station_freq', 'commuter_carpool_to_station_freq', 'commuter_driven_to_station_freq', 'commuter_bus_to_station_freq', 'no_walk_reason', 'no_bike_reason', 'drive_reason', 'feelings', 'problem_areas', 'drivers_are_safe', 'bicyclists_are_safe', 'suggested_improvements', 'additional_comments', 'owns_business', 'business_type', 'business_space', 'business_pedestrian_synergy', 'business_bicyclists_synergy', 'business_bike_rack_interest', 'business_promotion_interest', 'business_additional_comments', 'final_comments', 'contact_interest', 'contact_info', 'wants_pdf' ]
categorical_columns = [ 'neighborhood', 'demographic', 'schools', 'child_bus_freq', 'child_bike_freq', 'child_driven_freq', 'child_drive_freq', 'child_walk_freq', 'child_drive_reason', 'child_no_walk_reason', 'child_no_bike_reason', 'walk_freq', 'bike_freq', 'bikes_on_sidewalk', 'self_jog_frequency', 'commutes', 'child_self_school', 'child_self_bus_freq', 'child_self_bike_freq', 'child_self_driven_freq', 'child_self_drive_freq', 'child_self_walk_freq', 'child_self_commutes', 'child_self_has_children', 'commuter_distance', 'commuter_type', 'commuter_walk_to_station_freq', 'commuter_bike_to_station_freq', 'commuter_drive_to_station_freq', 'commuter_carpool_to_station_freq', 'commuter_driven_to_station_freq', 'commuter_bus_to_station_freq', 'no_walk_reason', 'no_bike_reason', 'drive_reason', 'drivers_are_safe', 'bicyclists_are_safe', 'suggested_improvements', 'owns_business', 'business_type', 'business_space', 'business_pedestrian_synergy', 'business_bicyclists_synergy', 'business_bike_rack_interest', 'business_promotion_interest', 'contact_interest', 'wants_pdf' ]
for col in categorical_columns :
    df[col] = df[col].astype('category')
    continue
    
# show the top few rows
df.head()
# Out:
#                  date          neighborhood  \
# 0 2019-02-27 15:32:07            Mount Airy
# 1 2019-02-27 17:03:24                Harmon
# 2 2019-02-28 08:41:08  Old Post Road N area
# 3 2019-03-07 10:27:34        Croton Landing
# 4 2019-03-19 20:27:28                Harmon
#
#                                         demographic       schools  \
# 0     Adult with school age children living with me           PVC
# 1     Adult with school age children living with me  Homeschooled
# 2     Adult with school age children living with me           PVC
# 3  Adult with no school age children living with me           NaN
# 4     Adult with school age children living with me           CET
#
#                    child_bus_freq  \
# 0  Every day, or almost every day
# 1                 Rarely or never
# 2                 Rarely or never
# 3                             NaN
# 4  Every day, or almost every day
#
#                                child_bike_freq    child_driven_freq  \
# 0          Rarely or never - for other reasons  Once every few days
# 1          Rarely or never - for other reasons  Once every few days
# 2                              Once in a while      Once in a while
# 3                                          NaN                  NaN
# 4  Rarely or never - my children are too young      Once in a while
#
#                               child_drive_freq  \
# 0  Rarely or never - my children are too young
# 1          Rarely or never - for other reasons
# 2  Rarely or never - my children are too young
# 3                                          NaN
# 4  Rarely or never - my children are too young
#
#                                child_walk_freq  \
# 0                              Once in a while
# 1          Rarely or never - for other reasons
# 2               Every day, or almost every day
# 3                                          NaN
# 4  Rarely or never - my children are too young
#
#                                   child_drive_reason    ...    business_space  \
# 0       The bus schedule does not match our schedule    ...               NaN
# 1  Our daughter is homeschooled, but attends alte...    ...               NaN
# 2       No - we do not drive, or prefer not to drive    ...               NaN
# 3                                                NaN    ...               NaN
# 4                  Early morning program once a week    ...               NaN
#
#   business_pedestrian_synergy business_bicyclists_synergy  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   business_bike_rack_interest business_promotion_interest  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   business_additional_comments final_comments contact_interest  \
# 0                          NaN            NaN              Yes
# 1                          NaN            NaN              Yes
# 2                          NaN            NaN              Yes
# 3                          NaN            NaN              NaN
# 4                          NaN            NaN              Yes
#
#               contact_info wants_pdf
# 0  elizamccarthy@gmail.com        No
# 1           Amos Bloomberg        No
# 2              Matt Arnold        No
# 3                      NaN       NaN
# 4           Daniel Castner       Yes
#
# [5 rows x 54 columns]

# %% [markdown]
# ## Clean up neighborhood names
# Neighorhood names were verbose in the actual survey... and some respondents wrote their own locations.  We group those respondents into their nearest neighborhoods and use consistent neighborhood names here.

# %%
df['neighborhood'] = df['neighborhood'].str.strip() # remove white space
df['neighborhood'] = df['neighborhood'].replace({
    
    # simplifying neighborhood names
    'Albany Post Road / Prickly Pear Hill / Scenic Dr area': 'Albany Post Road', 
    'Cortlandt outside of Croton': 'Cortlandt',
    'Old Post Road N area': 'Old Post Road North',
    'Quaker Ridge / Quaker Bridge area': 'Quaker Ridge',
    'Sunset Park area': 'Sunset Park',
    'Teatown area': 'Teatown',
    'Upper Village (the area nearest the Black Cow coffee shop)': 'Upper Village',

    # lumping CET/library area into Harmon
    'CET': 'Harmon', 
    'By CET': 'Harmon',
    'By the library/cemetery/CET': 'Harmon',
    'End of Cleveland near path': 'Harmon',
    'Cleveland near CET/Library': 'Harmon',
    'Cleveland/Park': 'Harmon',
    'Duck Pond': 'Harmon',
    'Harmon Park': 'Harmon',
    'Irving Ave': 'Harmon',
    'Ridge Rd.': 'Harmon',
    'Truesdale Drive': 'Harmon',
    'along the croton river': 'Harmon',
    'Behind high school': 'Harmon',
    
    # lumping Old Post Road South and Sunset Park together
    'Old Post Road S': 'Sunset Park', 
    
    # lumping North Riverside area into Croton Landing
    'North Riverside': 'Croton Landing',
    'Palmer on High St': 'Croton Landing',
    'lower village': 'Croton Landing',
    'Brook St': 'Croton Landing',
    
    # lumping Old Post Road North and Croton Landing together
    'Croton Landing': 'Old Post Road North', 
    
    # lumping nearby streets into Upper Village
    'Bari Manor': 'Upper Village',
    'Harrison st': 'Upper Village',
    'Wells Ave': 'Upper Village',
    
    # lumping Batten Rd and Crompond Rd areas with Mount Airy
    'Batten Road': 'Mount Airy',
    'The trails': 'Mount Airy',
    '129 near dam': 'Mount Airy', 
    
    #lumping Teatown into Quaker Ridge, since there were few Teatown respondents
    'Teatown': 'Quaker Ridge' 
})

df['neighborhood'].value_counts()
# Out:
# Harmon                 158
# Upper Village          111
# Old Post Road North     71
# Mount Airy              60
# Sunset Park             46
# Albany Post Road        29
# Half Moon Bay           19
# Quaker Ridge            10
# Cortlandt                9
# Ossining                 1
# Wells/Beekman Area       1
# Name: neighborhood, dtype: int64

# %% [markdown]
# ## Clean up demographics
# Some respondents indicated their own demographic titles... we're standardizing these.

# %%
df['demographic'] = df['demographic'].str.strip() # remove white space
df['demographic'] = df['demographic'].replace({
    
    # creating new category for adults with small children
    'Adult with a 22 year old and a 3 year old living with me': 'Adult with small child',
    'Adult with an infant': 'Adult with small child',
    'Adult with new baby': 'Adult with small child',
    'Adult with toddler': 'Adult with small child',
    'Adult with toddler living with me': 'Adult with small child',
    'Adult with toddlers living with me': 'Adult with small child',
    'Adult with young children': 'Adult with small child',
    'Adult with young children living with me': 'Adult with small child',
    'Adult with 3year old': 'Adult with small child',
    
    # lump adults with infants & toddlers into adults with no school age children
    'Adult with small child': 'Adult with no school age children living with me',
    'Adult with spouse and adult children living with us.': 'Adult with no school age children living with me',
    
    # lumping adults with college kids into the adults with no school age children category
    'adult with post college child living with me': 'Adult with no school age children living with me',
    'Adult with College Children': 'Adult with no school age children living with me',
    'Adult with College Children': 'Adult with no school age children living with me'

})    

# simplify response text
df['demographic'] = df['demographic'].replace({
    'Adult with school age children living with me': 'Adult with school kid',
    'Adult with no school age children living with me': 'Adult without school kid',
    'College student': 'College kid',
    'High School student': 'High School kid',
    'Middle School student': 'Middle School kid',
})

df['demographic'].value_counts()
# Out:
# Adult with school kid                                          210
# Adult without school kid                                       168
# Senior                                                         134
# College kid                                                      5
# High School kid                                                  3
# Middle School kid                                                1
# Adult with school age children and a senior living with me.      1
# Name: demographic, dtype: int64

# %% [markdown]
# ## Split up columns with comma-separated values into separate columns

# %%
# get a dataframe with each school in its own column, and 0 or 1 as the values indicating which row indicated that school
#df2 = df[pd.notnull(df['schools'])]
#df3 = df2['schools'].str.get_dummies(sep=', ')
#for column in df3:
#    column = column.strip() #remove whitespace
#df3

# split a column with comma-separated values into separate columns
def breakout_comma_separated_values(old_column_name):
    # expand comma-separated values in the column into their own dataframe with multiple columns for each value
    df[old_column_name] = df[old_column_name].str.split(', ') #split by comma into a list
    series = df[old_column_name].apply(pd.Series) # convert each list into a series

    # rename each variable with a prefixed column name in a new dataframe
    new_df = series.rename(columns = lambda x : old_column_name + '_' + str(x))
    
    # return the new dataframe
    return new_df


# try it out
fields = [ 'schools', 'child_drive_reason', 'child_no_walk_reason', 'child_no_bike_reason', 'commuter_distance', 'no_walk_reason', 'no_bike_reason', 'drive_reason' ]
#fields = ['schools']

for column_name in fields:
    
    # split up the column into multiple columns
    df2 = breakout_comma_separated_values(column_name)
    
    # join the new dataframe to the original dataframe
    df = pd.concat([df[:], df2[:]], axis=1)

    # delete the original column from the original dataframe
    del df[column_name]

    display(df2)
    
column_names = [c for c in df]
display(column_names)
# Out:
#                                           schools_0  \
# 0                                               PVC
# 1                                      Homeschooled
# 2                                               PVC
# 3                                               NaN
# 4                                               CET
# 5                                               NaN
# 6                                               PVC
# 7                                               NaN
# 8                                               PVC
# 9                                               NaN
# 10                                     Homeschooled
# 11                                             CHHS
# 12                                             CHHS
# 13                                              CET
# 14                                              CET
# 15                                     Homeschooled
# 16                                              CET
# 17                     Nursery School in Briarcliff
# 18                                              CET
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              CET
# 26                                              NaN
# 27                                              PVC
# 28                                              NaN
# 29                                              CET
# ..                                              ...
# 495                                             NaN
# 496                                             NaN
# 497                                             CET
# 498                                             NaN
# 499                                             NaN
# 500                                            CHHS
# 501                          Saint Augustine School
# 502                                             CET
# 503                                             CET
# 504                                             NaN
# 505                                             NaN
# 506                                             CET
# 507                                             NaN
# 508                                             CET
# 509               Circle School/Asbury Play & Learn
# 510                                             CET
# 511                                             CET
# 512                                             CET
# 513  Asbury - preschool (will attend CET next year)
# 514                                            CHHS
# 515                                             CET
# 516                                             NaN
# 517                                             NaN
# 518                                             NaN
# 519                                             CET
# 520                                             NaN
# 521                                             NaN
# 522                                             NaN
# 523                                             CET
# 524                                             PVC
#
#                             schools_1 schools_2
# 0                                 NaN       NaN
# 1                                 NaN       NaN
# 2                                 NaN       NaN
# 3                                 NaN       NaN
# 4                                 NaN       NaN
# 5                                 NaN       NaN
# 6                                 NaN       NaN
# 7                                 NaN       NaN
# 8                                 NaN       NaN
# 9                                 NaN       NaN
# 10                                NaN       NaN
# 11                                NaN       NaN
# 12                                NaN       NaN
# 13                                PVC       NaN
# 14                                PVC       NaN
# 15                                NaN       NaN
# 16                                NaN       NaN
# 17                                NaN       NaN
# 18                                NaN       NaN
# 19                                NaN       NaN
# 20                                NaN       NaN
# 21                                NaN       NaN
# 22                                NaN       NaN
# 23                                NaN       NaN
# 24                                NaN       NaN
# 25                                NaN       NaN
# 26                                NaN       NaN
# 27                                NaN       NaN
# 28                                NaN       NaN
# 29                                PVC       NaN
# ..                                ...       ...
# 495                               NaN       NaN
# 496                               NaN       NaN
# 497                               NaN       NaN
# 498                               NaN       NaN
# 499                               NaN       NaN
# 500                               NaN       NaN
# 501  Ossining; Happy Hearts on Hudson       NaN
# 502                               PVC       NaN
# 503                               PVC       NaN
# 504                               NaN       NaN
# 505                               NaN       NaN
# 506              Windward and Hackley       NaN
# 507                               NaN       NaN
# 508                              CHHS       NaN
# 509                               NaN       NaN
# 510                               NaN       NaN
# 511                               NaN       NaN
# 512                               NaN       NaN
# 513                               NaN       NaN
# 514                               NaN       NaN
# 515                               PVC      CHHS
# 516                               NaN       NaN
# 517                               NaN       NaN
# 518                               NaN       NaN
# 519                               PVC       NaN
# 520                               NaN       NaN
# 521                               NaN       NaN
# 522                               NaN       NaN
# 523                               PVC       NaN
# 524                              CHHS       NaN
#
# [525 rows x 3 columns]
#                                   child_drive_reason_0  \
# 0         The bus schedule does not match our schedule
# 1                         Our daughter is homeschooled
# 2                                 No - we do not drive
# 3                                                  NaN
# 4                    Early morning program once a week
# 5                                                  NaN
# 6                                 No - we do not drive
# 7                                                  NaN
# 8         The bus schedule does not match our schedule
# 9                                                  NaN
# 10                            We don’t drive to school
# 11                         Our own personal preference
# 12                         Our own personal preference
# 13                                No - we do not drive
# 14                                No - we do not drive
# 15                      Safety concerns with bicycling
# 16   I only drive them if they miss the bus or have...
# 17                        Not an option for our school
# 18                                No - we do not drive
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                No - we do not drive
# 26                                                 NaN
# 27                                No - we do not drive
# 28                                                 NaN
# 29        The bus schedule does not match our schedule
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                               No - we do not drive
# 498                                                NaN
# 499                                                NaN
# 500                        Our own personal preference
# 501                                  Older chld busses
# 502                               No - we do not drive
# 503                     Safety concerns with bicycling
# 504                                                NaN
# 505                                                NaN
# 506                               No - we do not drive
# 507                                                NaN
# 508       The bus schedule does not match our schedule
# 509                               No - we do not drive
# 510                     Safety concerns with bicycling
# 511                               No - we do not drive
# 512       The bus schedule does not match our schedule
# 513                        Our own personal preference
# 514                               No - we do not drive
# 515                       Safety concerns with walking
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519            Bad weather for my PVC girls to walk in
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                        Our own personal preference
# 524                      inclement weather or lateness
#
#                                   child_drive_reason_1 child_drive_reason_2  \
# 0                                                  NaN                  NaN
# 1    but attends alternative education a few times ...                  NaN
# 2                               or prefer not to drive                  NaN
# 3                                                  NaN                  NaN
# 4                                                  NaN                  NaN
# 5                                                  NaN                  NaN
# 6                               or prefer not to drive                  NaN
# 7                                                  NaN                  NaN
# 8                                                  NaN                  NaN
# 9                                                  NaN                  NaN
# 10                                                 NaN                  NaN
# 11                                                 NaN                  NaN
# 12                                                 NaN                  NaN
# 13                              or prefer not to drive                  NaN
# 14                              or prefer not to drive                  NaN
# 15                                                 NaN                  NaN
# 16                                                 NaN                  NaN
# 17                                                 NaN                  NaN
# 18                              or prefer not to drive                  NaN
# 19                                                 NaN                  NaN
# 20                                                 NaN                  NaN
# 21                                                 NaN                  NaN
# 22                                                 NaN                  NaN
# 23                                                 NaN                  NaN
# 24                                                 NaN                  NaN
# 25                              or prefer not to drive                  NaN
# 26                                                 NaN                  NaN
# 27                              or prefer not to drive                  NaN
# 28                                                 NaN                  NaN
# 29                                                 NaN                  NaN
# ..                                                 ...                  ...
# 495                                                NaN                  NaN
# 496                                                NaN                  NaN
# 497                             or prefer not to drive                  NaN
# 498                                                NaN                  NaN
# 499                                                NaN                  NaN
# 500                                                NaN                  NaN
# 501  younger child needs to be driven to happy hearts.                  NaN
# 502                             or prefer not to drive                  NaN
# 503                                                NaN                  NaN
# 504                                                NaN                  NaN
# 505                                                NaN                  NaN
# 506                             or prefer not to drive                  NaN
# 507                                                NaN                  NaN
# 508                                                NaN                  NaN
# 509                             or prefer not to drive                  NaN
# 510                                                NaN                  NaN
# 511                             or prefer not to drive                  NaN
# 512                                                NaN                  NaN
# 513                                                NaN                  NaN
# 514                             or prefer not to drive                  NaN
# 515                                                NaN                  NaN
# 516                                                NaN                  NaN
# 517                                                NaN                  NaN
# 518                                                NaN                  NaN
# 519                                                NaN                  NaN
# 520                                                NaN                  NaN
# 521                                                NaN                  NaN
# 522                                                NaN                  NaN
# 523                                                NaN                  NaN
# 524                                                NaN                  NaN
#
#     child_drive_reason_3
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16                   NaN
# 17                   NaN
# 18                   NaN
# 19                   NaN
# 20                   NaN
# 21                   NaN
# 22                   NaN
# 23                   NaN
# 24                   NaN
# 25                   NaN
# 26                   NaN
# 27                   NaN
# 28                   NaN
# 29                   NaN
# ..                   ...
# 495                  NaN
# 496                  NaN
# 497                  NaN
# 498                  NaN
# 499                  NaN
# 500                  NaN
# 501                  NaN
# 502                  NaN
# 503                  NaN
# 504                  NaN
# 505                  NaN
# 506                  NaN
# 507                  NaN
# 508                  NaN
# 509                  NaN
# 510                  NaN
# 511                  NaN
# 512                  NaN
# 513                  NaN
# 514                  NaN
# 515                  NaN
# 516                  NaN
# 517                  NaN
# 518                  NaN
# 519                  NaN
# 520                  NaN
# 521                  NaN
# 522                  NaN
# 523                  NaN
# 524                  NaN
#
# [525 rows x 4 columns]
#                                 child_no_walk_reason_0  \
# 0                              We live too far to walk
# 1                              same as previous answer
# 2                                 No - they walk a lot
# 3                                                  NaN
# 4                              We live too far to walk
# 5                                                  NaN
# 6                                 No - they walk a lot
# 7                                                  NaN
# 8                                          Dicey route
# 9                                                  NaN
# 10                           Fear of dangerous driving
# 11                                                 NaN
# 12                          We don't have time to walk
# 13                             We live too far to walk
# 14                             We live too far to walk
# 15                             We live too far to walk
# 16                          We don't have time to walk
# 17                             We live too far to walk
# 18                             We live too far to walk
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                          We don't have time to walk
# 26                                                 NaN
# 27                                No - they walk a lot
# 28                                                 NaN
# 29                           Fear of dangerous driving
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
# 500                            We live too far to walk
# 501                            We live too far to walk
# 502                            We live too far to walk
# 503                            We live too far to walk
# 504                                                NaN
# 505                                                NaN
# 506  He is just entering the grade you can walk to ...
# 507                                                NaN
# 508                            We live too far to walk
# 509                               No - they walk a lot
# 510                            We live too far to walk
# 511                                                NaN
# 512                                          To young
# 513                            We live too far to walk
# 514                            We live too far to walk
# 515  Lack of adequate crosswalks at busy intersections
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                               No - they walk a lot
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                               No - they walk a lot
# 524                               No - they walk a lot
#
#                                 child_no_walk_reason_1  \
# 0                           We don't have time to walk
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                   with no sidewalks.
# 9                                                  NaN
# 10   My child doesn’t walk to school due to homesch...
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                          We don't have time to walk
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                          Lack of adequate sidewalks
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                          Lack of adequate sidewalks
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
# 500                                                NaN
# 501  Walking to Town on Mt. Airy Road is a Death-Wi...
# 502                                                NaN
# 503                          Fear of dangerous driving
# 504                                                NaN
# 505                                                NaN
# 506                                                NaN
# 507                                                NaN
# 508                                                NaN
# 509                                                NaN
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                                                NaN
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
# 524                                                NaN
#
#                                 child_no_walk_reason_2  \
# 0                            Fear of dangerous drivers
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                      but she had to
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29   Lack of adequate crosswalks at busy intersections
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
# 500                                                NaN
# 501                                                NaN
# 502                                                NaN
# 503                         Lack of adequate sidewalks
# 504                                                NaN
# 505                                                NaN
# 506                                                NaN
# 507                                                NaN
# 508                                                NaN
# 509                                                NaN
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                                                NaN
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
# 524                                                NaN
#
#                             child_no_walk_reason_3 child_no_walk_reason_4
# 0                                              NaN                    NaN
# 1                                              NaN                    NaN
# 2                                              NaN                    NaN
# 3                                              NaN                    NaN
# 4                                              NaN                    NaN
# 5                                              NaN                    NaN
# 6                                              NaN                    NaN
# 7                                              NaN                    NaN
# 8                                              NaN                    NaN
# 9                                              NaN                    NaN
# 10        i’d be afraid about drivers and speeding                    NaN
# 11                                             NaN                    NaN
# 12                                             NaN                    NaN
# 13                                             NaN                    NaN
# 14                                             NaN                    NaN
# 15                                             NaN                    NaN
# 16                                             NaN                    NaN
# 17                                             NaN                    NaN
# 18                                             NaN                    NaN
# 19                                             NaN                    NaN
# 20                                             NaN                    NaN
# 21                                             NaN                    NaN
# 22                                             NaN                    NaN
# 23                                             NaN                    NaN
# 24                                             NaN                    NaN
# 25                                             NaN                    NaN
# 26                                             NaN                    NaN
# 27                                             NaN                    NaN
# 28                                             NaN                    NaN
# 29   Lack of crossing guards at busy intersections                    NaN
# ..                                             ...                    ...
# 495                                            NaN                    NaN
# 496                                            NaN                    NaN
# 497                                            NaN                    NaN
# 498                                            NaN                    NaN
# 499                                            NaN                    NaN
# 500                                            NaN                    NaN
# 501                                            NaN                    NaN
# 502                                            NaN                    NaN
# 503                                            NaN                    NaN
# 504                                            NaN                    NaN
# 505                                            NaN                    NaN
# 506                                            NaN                    NaN
# 507                                            NaN                    NaN
# 508                                            NaN                    NaN
# 509                                            NaN                    NaN
# 510                                            NaN                    NaN
# 511                                            NaN                    NaN
# 512                                            NaN                    NaN
# 513                                            NaN                    NaN
# 514                                            NaN                    NaN
# 515                                            NaN                    NaN
# 516                                            NaN                    NaN
# 517                                            NaN                    NaN
# 518                                            NaN                    NaN
# 519                                            NaN                    NaN
# 520                                            NaN                    NaN
# 521                                            NaN                    NaN
# 522                                            NaN                    NaN
# 523                                            NaN                    NaN
# 524                                            NaN                    NaN
#
# [525 rows x 5 columns]
#                child_no_bike_reason_0  \
# 0                               Hills
# 1             Same as previous answer
# 2         Lack of adequate bike lanes
# 3                                 NaN
# 4    My child is too young to bicycle
# 5                                 NaN
# 6           Fear of dangerous driving
# 7                                 NaN
# 8         Our own personal preference
# 9                                 NaN
# 10          Fear of dangerous driving
# 11                                NaN
# 12        Our own personal preference
# 13          Fear of dangerous driving
# 14          Fear of dangerous driving
# 15   My child is too young to bicycle
# 16   My child is too young to bicycle
# 17         We live too far to bicycle
# 18   My child is too young to bicycle
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25   My child is too young to bicycle
# 26                                NaN
# 27          Fear of dangerous driving
# 28                                NaN
# 29          Fear of dangerous driving
# ..                                ...
# 495                               NaN
# 496                               NaN
# 497                               NaN
# 498                               NaN
# 499                               NaN
# 500         Fear of dangerous driving
# 501        We live too far to bicycle
# 502  My child is too young to bicycle
# 503        We live too far to bicycle
# 504                               NaN
# 505                               NaN
# 506                   See above other
# 507                               NaN
# 508       Lack of adequate bike lanes
# 509  My child is too young to bicycle
# 510       Lack of adequate bike lanes
# 511                               NaN
# 512  My child is too young to bicycle
# 513  My child is too young to bicycle
# 514        We live too far to bicycle
# 515         Fear of dangerous driving
# 516                               NaN
# 517                               NaN
# 518                               NaN
# 519          Easier to walk than bike
# 520                               NaN
# 521                               NaN
# 522                               NaN
# 523                             Hills
# 524       Lack of adequate bike lanes
#
#                                 child_no_bike_reason_1  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                          Lack of adequate bike lanes
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                         Lack of adequate bike lanes
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                          We live too far to bicycle
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
# 500                                              Hills
# 501  Biking to Town on Mt. Airy Road is a Death-Wis...
# 502                                              Hills
# 503                          Fear of dangerous driving
# 504                                                NaN
# 505                                                NaN
# 506                                                NaN
# 507                                                NaN
# 508                                                NaN
# 509                                                NaN
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                        Lack of adequate bike lanes
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
# 520                                                NaN
# 521                                                NaN
# 522                                                NaN
# 523                                                NaN
# 524                                              Hills
#
#           child_no_bike_reason_2 child_no_bike_reason_3
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# 5                            NaN                    NaN
# 6                            NaN                    NaN
# 7                            NaN                    NaN
# 8                            NaN                    NaN
# 9                            NaN                    NaN
# 10                           NaN                    NaN
# 11                           NaN                    NaN
# 12                           NaN                    NaN
# 13                           NaN                    NaN
# 14                           NaN                    NaN
# 15                           NaN                    NaN
# 16                           NaN                    NaN
# 17                           NaN                    NaN
# 18                           NaN                    NaN
# 19                           NaN                    NaN
# 20                           NaN                    NaN
# 21                           NaN                    NaN
# 22                           NaN                    NaN
# 23                           NaN                    NaN
# 24                           NaN                    NaN
# 25                           NaN                    NaN
# 26                           NaN                    NaN
# 27                           NaN                    NaN
# 28                           NaN                    NaN
# 29                           NaN                    NaN
# ..                           ...                    ...
# 495                          NaN                    NaN
# 496                          NaN                    NaN
# 497                          NaN                    NaN
# 498                          NaN                    NaN
# 499                          NaN                    NaN
# 500                          NaN                    NaN
# 501                          NaN                    NaN
# 502                          NaN                    NaN
# 503  Lack of adequate bike lanes                    NaN
# 504                          NaN                    NaN
# 505                          NaN                    NaN
# 506                          NaN                    NaN
# 507                          NaN                    NaN
# 508                          NaN                    NaN
# 509                          NaN                    NaN
# 510                          NaN                    NaN
# 511                          NaN                    NaN
# 512                          NaN                    NaN
# 513                          NaN                    NaN
# 514                          NaN                    NaN
# 515                          NaN                    NaN
# 516                          NaN                    NaN
# 517                          NaN                    NaN
# 518                          NaN                    NaN
# 519                          NaN                    NaN
# 520                          NaN                    NaN
# 521                          NaN                    NaN
# 522                          NaN                    NaN
# 523                          NaN                    NaN
# 524                          NaN                    NaN
#
# [525 rows x 4 columns]
#        commuter_distance_0 commuter_distance_1 commuter_distance_2
# 0                      NaN                 NaN                 NaN
# 1    To/From New York City                 NaN                 NaN
# 2    To/From New York City                 NaN                 NaN
# 3    To/From New York City                 NaN                 NaN
# 4    To/From New York City                 NaN                 NaN
# 5    To/From New York City                 NaN                 NaN
# 6    To/from New York City                 NaN                 NaN
# 7                      NaN                 NaN                 NaN
# 8                      NaN                 NaN                 NaN
# 9            Within Croton                 NaN                 NaN
# 10                     NaN                 NaN                 NaN
# 11      Within Westchester                 NaN                 NaN
# 12                     NaN                 NaN                 NaN
# 13                     NaN                 NaN                 NaN
# 14   To/from New York City                 NaN                 NaN
# 15      Within Westchester                 NaN                 NaN
# 16                     NaN                 NaN                 NaN
# 17                     NaN                 NaN                 NaN
# 18      Within Westchester                 NaN                 NaN
# 19   To/from New York City                 NaN                 NaN
# 20           Within Croton                 NaN                 NaN
# 21                     NaN                 NaN                 NaN
# 22           Within Croton                 NaN                 NaN
# 23      Within Westchester                 NaN                 NaN
# 24   To/from New York City                 NaN                 NaN
# 25                     NaN                 NaN                 NaN
# 26   To/from New York City                 NaN                 NaN
# 27   To/from New York City                 NaN                 NaN
# 28                     NaN                 NaN                 NaN
# 29                     NaN                 NaN                 NaN
# ..                     ...                 ...                 ...
# 495  To/from New York City                 NaN                 NaN
# 496  To/from New York City                 NaN                 NaN
# 497  To/from New York City                 NaN                 NaN
# 498     Within Westchester                 NaN                 NaN
# 499                    NaN                 NaN                 NaN
# 500  To/from New York City                 NaN                 NaN
# 501     Within Westchester                 NaN                 NaN
# 502  To/from New York City                 NaN                 NaN
# 503          Within Croton                 NaN                 NaN
# 504          Within Croton                 NaN                 NaN
# 505  To/from New York City                 NaN                 NaN
# 506                    NaN                 NaN                 NaN
# 507     Within Westchester                 NaN                 NaN
# 508                    NaN                 NaN                 NaN
# 509  To/from New York City                 NaN                 NaN
# 510                    NaN                 NaN                 NaN
# 511  To/from New York City                 NaN                 NaN
# 512               Rockland                 NaN                 NaN
# 513  To/from New York City                 NaN                 NaN
# 514  To/from New York City                 NaN                 NaN
# 515  To/from New York City                 NaN                 NaN
# 516                    NaN                 NaN                 NaN
# 517                    NaN                 NaN                 NaN
# 518  To/from New York City                 NaN                 NaN
# 519                    NaN                 NaN                 NaN
# 520  To/from New York City                 NaN                 NaN
# 521  To/from New York City                 NaN                 NaN
# 522     Within Westchester                 NaN                 NaN
# 523          Within Croton                 NaN                 NaN
# 524         to Connecticut                 NaN                 NaN
#
# [525 rows x 3 columns]
#                no_walk_reason_0  \
# 0             No - I walk a lot
# 1             No - I walk a lot
# 2             No - I walk a lot
# 3             No - I walk a lot
# 4             No - I walk a lot
# 5             No - I walk a lot
# 6             No - I walk a lot
# 7             No - I walk a lot
# 8             No - I walk a lot
# 9     I don't have time to walk
# 10   Lack of adequate sidewalks
# 11            No - I walk a lot
# 12            No - I walk a lot
# 13       I live too far to walk
# 14       I live too far to walk
# 15    Fear of dangerous driving
# 16    I don't have time to walk
# 17    I don't have time to walk
# 18            No - I walk a lot
# 19       I live too far to walk
# 20    I don't have time to walk
# 21    Fear of dangerous driving
# 22            No - I walk a lot
# 23   My own personal preference
# 24       I live too far to walk
# 25    Fear of dangerous driving
# 26    I don't have time to walk
# 27   Lack of adequate sidewalks
# 28   Lack of adequate sidewalks
# 29    Fear of dangerous driving
# ..                          ...
# 495      I live too far to walk
# 496  My own personal preference
# 497           No - I walk a lot
# 498   I don't have time to walk
# 499           No - I walk a lot
# 500  Lack of adequate sidewalks
# 501           No - I walk a lot
# 502           No - I walk a lot
# 503      I live too far to walk
# 504           No - I walk a lot
# 505  Lack of adequate sidewalks
# 506           No - I walk a lot
# 507           No - I walk a lot
# 508  Lack of adequate sidewalks
# 509           No - I walk a lot
# 510   Fear of dangerous driving
# 511   I don't have time to walk
# 512                         NaN
# 513  Lack of adequate sidewalks
# ...
# 8                                 Time saving to drive
# 9                           My own personal preference
# 10                I don't have time to walk or bicycle
# 11                      Safety concerns with bicycling
# 12                          My own personal preference
# 13                      Safety concerns with bicycling
# 14                      Safety concerns with bicycling
# 15                I don't have time to walk or bicycle
# 16                I don't have time to walk or bicycle
# 17                I don't have time to walk or bicycle
# 18                                                 NaN
# 19                I don't have time to walk or bicycle
# 20                          My own personal preference
# 21                        Safety concerns with walking
# 22                                                 NaN
# 23                          My own personal preference
# 24                                             Too far
# 25                                 No - I do not drive
# 26                I need better carriers for my things
# 27                I don't have time to walk or bicycle
# 28                        Safety concerns with walking
# 29                        Safety concerns with walking
# ..                                                 ...
# 495               I don't have time to walk or bicycle
# 496               I don't have time to walk or bicycle
# 497                         My own personal preference
# 498               I don't have time to walk or bicycle
# 499                         My own personal preference
# 500                         My own personal preference
# 501               I don't have time to walk or bicycle
# 502                         My own personal preference
# 503                     Safety concerns with bicycling
# 504                         My own personal preference
# 505                       Safety concerns with walking
# 506               I don't have time to walk or bicycle
# 507               I don't have time to walk or bicycle
# 508                         My own personal preference
# 509  Young children and the walk is often too far t...
# 510                     Safety concerns with bicycling
# 511               I don't have time to walk or bicycle
# 512                                                NaN
# 513                     Safety concerns with bicycling
# 514               I don't have time to walk or bicycle
# 515               I don't have time to walk or bicycle
# 516               Hill too steep to my home for biking
# 517               I don't have time to walk or bicycle
# 518                                No - I do not drive
# 519                 Distance to grocery stores and gym
# 520               I don't have time to walk or bicycle
# 521                                            Too far
# 522                         My own personal preference
# 523               I don't have time to walk or bicycle
# 524                     Safety concerns with bicycling
#
#                      drive_reason_1  \
# 0                               NaN
# 1            or prefer not to drive
# 2                               NaN
# 3            or prefer not to drive
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 8                         at times.
# 9                               NaN
# 10                              NaN
# 11                              NaN
# 12                              NaN
# 13                              NaN
# 14                              NaN
# 15                              NaN
# 16                              NaN
# 17   Safety concerns with bicycling
# 18                              NaN
# 19                              NaN
# 20                              NaN
# 21   Safety concerns with bicycling
# 22                              NaN
# 23                              NaN
# 24                              NaN
# 25           or prefer not to drive
# 26                              NaN
# 27                              NaN
# 28   Safety concerns with bicycling
# 29                              NaN
# ..                              ...
# 495                             NaN
# 496      My own personal preference
# 497                             NaN
# 498                             NaN
# 499                             NaN
# 500                             NaN
# 501    Safety concerns with walking
# 502                             NaN
# 503                             NaN
# 504                             NaN
# 505  Safety concerns with bicycling
# 506                             NaN
# 507                             NaN
# 508                             NaN
# 509                             NaN
# 510                             NaN
# 511                             NaN
# 512                             NaN
# 513                             NaN
# 514                             NaN
# 515  Safety concerns with bicycling
# 516                             NaN
# 517      My own personal preference
# 518          or prefer not to drive
# 519                             NaN
# 520                             NaN
# 521                 takers too long
# 522                             NaN
# 523                             NaN
# 524                             NaN
#
#                                         drive_reason_2  \
# 0                                                  NaN
# 1                                          Convenience
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                 I always have my young kids with me
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 495                                                NaN
# 496                                                NaN
# 497                                                NaN
# 498                                                NaN
# 499                                                NaN
# 500                                                NaN
# 501                     Safety concerns with bicycling
# 502                                                NaN
# 503                                                NaN
# 504                                                NaN
# 505  I live on Dailey Drive off 129. 129 is horribl...
# 506                                                NaN
# 507                                                NaN
# 508                                                NaN
# 509                                                NaN
# 510                                                NaN
# 511                                                NaN
# 512                                                NaN
# 513                                                NaN
# 514                                                NaN
# 515                                                NaN
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
# 520                                                NaN
# 521                              can't carry groceries
# 522                                                NaN
# 523                                                NaN
# 524                                                NaN
#
#                               drive_reason_3     drive_reason_4 drive_reason_5
# 0                                        NaN                NaN            NaN
# 1                                        NaN                NaN            NaN
# 2                                        NaN                NaN            NaN
# 3                                        NaN                NaN            NaN
# 4                                        NaN                NaN            NaN
# 5                                        NaN                NaN            NaN
# 6                                        NaN                NaN            NaN
# 7                                        NaN                NaN            NaN
# 8                                        NaN                NaN            NaN
# 9                                        NaN                NaN            NaN
# 10                                       NaN                NaN            NaN
# 11                                       NaN                NaN            NaN
# 12                                       NaN                NaN            NaN
# 13                                       NaN                NaN            NaN
# 14                                       NaN                NaN            NaN
# 15                                       NaN                NaN            NaN
# 16                                       NaN                NaN            NaN
# 17                                       NaN                NaN            NaN
# 18                                       NaN                NaN            NaN
# 19                                       NaN                NaN            NaN
# 20                                       NaN                NaN            NaN
# 21                                       NaN                NaN            NaN
# 22                                       NaN                NaN            NaN
# 23                                       NaN                NaN            NaN
# 24                                       NaN                NaN            NaN
# 25                                       NaN                NaN            NaN
# 26                                       NaN                NaN            NaN
# 27                                       NaN                NaN            NaN
# 28                                       NaN                NaN            NaN
# 29                                       NaN                NaN            NaN
# ..                                       ...                ...            ...
# 495                                      NaN                NaN            NaN
# 496                                      NaN                NaN            NaN
# 497                                      NaN                NaN            NaN
# 498                                      NaN                NaN            NaN
# 499                                      NaN                NaN            NaN
# 500                                      NaN                NaN            NaN
# 501                                      NaN                NaN            NaN
# 502                                      NaN                NaN            NaN
# 503                                      NaN                NaN            NaN
# 504                                      NaN                NaN            NaN
# 505  at least to Quaker Bridge/Niles/Dailey!                NaN            NaN
# 506                                      NaN                NaN            NaN
# 507                                      NaN                NaN            NaN
# 508                                      NaN                NaN            NaN
# 509                                      NaN                NaN            NaN
# 510                                      NaN                NaN            NaN
# 511                                      NaN                NaN            NaN
# 512                                      NaN                NaN            NaN
# 513                                      NaN                NaN            NaN
# 514                                      NaN                NaN            NaN
# 515                                      NaN                NaN            NaN
# 516                                      NaN                NaN            NaN
# 517                                      NaN                NaN            NaN
# 518                                      NaN                NaN            NaN
# 519                                      NaN                NaN            NaN
# 520                                      NaN                NaN            NaN
# 521                             dry cleaning  etc. Back to home            NaN
# 522                                      NaN                NaN            NaN
# 523                                      NaN                NaN            NaN
# 524                                      NaN                NaN            NaN
#
# [525 rows x 6 columns]
# ['date',
#  'neighborhood',
#  'demographic',
#  'child_bus_freq',
#  'child_bike_freq',
#  'child_driven_freq',
#  'child_drive_freq',
#  'child_walk_freq',
#  'walk_freq',
#  'bike_freq',
#  'bikes_on_sidewalk',
#  'self_jog_frequency',
#  'commutes',
#  'child_self_school',
#  'child_self_bus_freq',
#  'child_self_bike_freq',
#  'child_self_driven_freq',
#  'child_self_drive_freq',
#  'child_self_walk_freq',
#  'child_self_commutes',
#  'child_self_has_children',
#  'commuter_type',
#  'commuter_walk_to_station_freq',
#  'commuter_bike_to_station_freq',
#  'commuter_drive_to_station_freq',
#  'commuter_carpool_to_station_freq',
#  'commuter_driven_to_station_freq',
#  'commuter_bus_to_station_freq',
#  'feelings',
#  'problem_areas',
#  'drivers_are_safe',
#  'bicyclists_are_safe',
#  'suggested_improvements',
#  'additional_comments',
#  'owns_business',
#  'business_type',
#  'business_space',
#  'business_pedestrian_synergy',
#  'business_bicyclists_synergy',
#  'business_bike_rack_interest',
#  'business_promotion_interest',
#  'business_additional_comments',
#  'final_comments',
#  'contact_interest',
#  'contact_info',
#  'wants_pdf',
#  'schools_0',
#  'schools_1',
#  'schools_2',
#  'child_drive_reason_0',
#  'child_drive_reason_1',
#  'child_drive_reason_2',
#  'child_drive_reason_3',
#  'child_no_walk_reason_0',
#  'child_no_walk_reason_1',
#  'child_no_walk_reason_2',
#  'child_no_walk_reason_3',
#  'child_no_walk_reason_4',
#  'child_no_bike_reason_0',
#  'child_no_bike_reason_1',
#  'child_no_bike_reason_2',
#  'child_no_bike_reason_3',
#  'commuter_distance_0',
#  'commuter_distance_1',
#  'commuter_distance_2',
#  'no_walk_reason_0',
#  'no_walk_reason_1',
#  'no_walk_reason_2',
#  'no_walk_reason_3',
#  'no_walk_reason_4',
#  'no_walk_reason_5',
#  'no_bike_reason_0',
#  'no_bike_reason_1',
#  'no_bike_reason_2',
#  'no_bike_reason_3',
#  'drive_reason_0',
#  'drive_reason_1',
#  'drive_reason_2',
#  'drive_reason_3',
#  'drive_reason_4',
#  'drive_reason_5']

# %% [markdown]
# ## Save cleaned up data to CSV file
# So it can be analyzed in subsequent programs.

# %%
df.to_csv('responses_scrubbed.csv', index=False)
