# %% [markdown]
# # Multiple answer cleanup
# Attempt at dealing with fields that contain comma-separated lists of answers from questions with multiple-select answer options that also allow respondents to enter their own 'other' answer.
#
# This notebook assumes the file named `responses_scrubbed_tagged.csv` has already been created by running the notebook named `free_text_tagging.ipynb`.  This notebook then creates a new data file called `responses_complete.csv` which has the complete set of final data.

# %%
import pandas as pd
import numpy as np
from IPython.display import display, Markdown, Latex

# %% [markdown]
# ## Load tagged data set
# This notebook assumes you have already scrubbed and tagged the data using the `free_text_tagging.ipynb` notebook first.

# %%
df = pd.read_csv('responses_scrubbed_tagged.csv', index_col=None, parse_dates=['date'])
df.sample(n=10) #random sample of rows
# Out:
#                    date         neighborhood               demographic  \
# 293 2019-07-04 14:04:42        Upper Village                    Senior
# 85  2019-07-03 16:14:37        Upper Village     Adult with school kid
# 63  2019-07-03 15:56:22                  NaN  Adult without school kid
# 196 2019-07-03 20:05:42        Half Moon Bay     Adult with school kid
# 314 2019-07-04 21:16:05               Harmon                    Senior
# 405 2019-07-08 19:25:43  Old Post Road North                    Senior
# 423 2019-07-09 13:27:16        Half Moon Bay  Adult without school kid
# 33  2019-07-03 15:44:54        Upper Village  Adult without school kid
# 260 2019-07-04 09:21:15               Harmon  Adult without school kid
# 206 2019-07-03 20:52:31        Upper Village                       NaN
#
#                      child_bus_freq                      child_bike_freq  \
# 293                             NaN                                  NaN
# 85                  Rarely or never                                  NaN
# 63                              NaN                                  NaN
# 196  Every day, or almost every day  Rarely or never - for other reasons
# 314                             NaN                                  NaN
# 405                             NaN                                  NaN
# 423                             NaN                                  NaN
# 33                              NaN                                  NaN
# 260                             NaN                                  NaN
# 206                             NaN                                  NaN
#
#     child_driven_freq                             child_drive_freq  \
# 293               NaN                                          NaN
# 85    Once in a while          Rarely or never - for other reasons
# 63                NaN                                          NaN
# 196   Rarely or never  Rarely or never - my children are too young
# 314               NaN                                          NaN
# 405               NaN                                          NaN
# 423               NaN                                          NaN
# 33                NaN                                          NaN
# 260               NaN                                          NaN
# 206               NaN                                          NaN
#
#                                  child_walk_freq  \
# 293                                          NaN
# 85           Rarely or never - for other reasons
# 63                                           NaN
# 196  Rarely or never - my children are too young
# 314                                          NaN
# 405                                          NaN
# 423                                          NaN
# 33                                           NaN
# 260                                          NaN
# 206                                          NaN
#
#                           walk_freq            bike_freq  \
# 293  Every day, or almost every day  Once every few days
# 85   Every day, or almost every day      Once in a while
# 63                  Once in a while      Once in a while
# 196             Once every few days      Rarely or never
# 314             Once every few days      Rarely or never
# 405             Once every few days  Once every few days
# 423             Once every few days      Once in a while
# 33              Once every few days      Rarely or never
# 260  Every day, or almost every day      Once in a while
# 206             Once every few days      Rarely or never
#
#                            ...                          \
# 293                        ...
# 85                         ...
# 63                         ...
# 196                        ...
# 314                        ...
# 405                        ...
# 423                        ...
# 33                         ...
# 260                        ...
# 206                        ...
#
#                                       no_bike_reason_2 no_bike_reason_3  \
# 293                                                NaN              NaN
# 85                   Places to lock and leave my bike               NaN
# 63                                                 NaN              NaN
# 196                                                NaN              NaN
# 314                                                NaN              NaN
# 405                                                NaN              NaN
# 423                                                NaN              NaN
# 33                                                 NaN              NaN
# 260  Bad behaviour by males. Police won't do anything.              NaN
# 206                                                NaN              NaN
#
#                                  drive_reason_0  \
# 293                  My own personal preference
# 85         I don't have time to walk or bicycle
# 63                   My own personal preference
# 196                                        Time
# 314        I don't have time to walk or bicycle
# 405                  My own personal preference
# 423              Safety concerns with bicycling
# 33   I’m frequently transporting a small child.
# 260                Safety concerns with walking
# 206                  My own personal preference
#
#                      drive_reason_1                        drive_reason_2  \
# 293                             NaN                                   NaN
# 85   Safety concerns with bicycling    Good places to leave and lock bike
# 63                              NaN                                   NaN
# 196                        distance  weather. We do walk places sometimes
# 314                             NaN                                   NaN
# 405                             NaN                                   NaN
# 423                             NaN                                   NaN
# 33                              NaN                                   NaN
# 260  Safety concerns with bicycling                                   NaN
# 206                             NaN                                   NaN
#
#     drive_reason_3 drive_reason_4 drive_reason_5  \
# 293            NaN            NaN            NaN
# 85             NaN            NaN            NaN
# 63             NaN            NaN            NaN
# 196            NaN            NaN            NaN
# 314            NaN            NaN            NaN
# 405            NaN            NaN            NaN
# 423            NaN            NaN            NaN
# 33             NaN            NaN            NaN
# 260            NaN            NaN            NaN
# 206            NaN            NaN            NaN
#
#                                           problem_tags  \
# 293  shoprite,129,hughes, n riverside,speeding,miss...
# 85   129,aggressive driving,driver awareness,speedi...
# 63       missing sidewalks, road surface,poor lighting
# 196  driver awareness,municipal place,missing sidew...
# 314               missing sidewalks,sidewalk condition
# 405                 speeding, s riverside, n riverside
# 423                                                NaN
# 33   sidewalk condition,cpa,five corners,aggressive...
# 260                                   driver awareness
# 206                                   cpa,dpw,num cars
#
#                                        suggestion_tags
# 293                         reduce speed,enforce speed
# 85                                        reduce speed
# 63                       more sidewalks, better lights
# 196                  more sidewalks,enforce crosswalks
# 314                  more sidewalks,maintain sidewalks
# 405                          enforce speed, bike lanes
# 423                                         bike lanes
# 33   bike lanes,more traffic lights,improve route 9...
# 260                                         bike lanes
# 206                           reduce num cars, carpool
#
# [10 rows x 80 columns]

# %% [markdown]
# ## Answer options to each question
# A dictionary containing lists of all the questions and the answer options that the user was asked to select from for each question in the Google Form.

# %%
# a dictionary of columns that contain comma-separated multiple answer options
multiple_answer_options = {
    'schools': ['CET', 'PVC', 'CHHS', 'Homeschooled'],
    'child_drive_reason': ['No - we do not drive, or prefer not to drive', 'Our own personal preference', 'Lack of available busing where we live', 'The bus schedule does not match our schedule', 'Safety concerns with buses', 'Safety concerns with walking', 'Safety concerns with bicycling', "My child's health condition"],
    'child_no_walk_reason': ['No - they walk a lot', 'My child does not like to walk', 'We live too far to walk', "We don't have time to walk", 'Fear of dangerous driving', 'Lack of adequate sidewalks', 'Lack of adequate crosswalks at busy intersections', 'Lack of crossing guards at busy intersections', "My child's health condition", 'Visually unappealing route'],
    'child_no_bike_reason': ['No - they bicycle a lot', 'My child does not like to bicycle', 'My child is too young to bicycle', 'We live too far to bicycle', 'Our own personal preference', 'Fear of dangerous driving', 'Lack of adequate bike lanes', "My child's health condition", 'Visually unappealing route', 'Hills'],
    'no_walk_reason': ['No - I walk a lot', 'I live too far to walk', 'I do not like to walk', "I don't have time to walk", 'Fear of dangerous driving', 'Lack of adequate sidewalks', 'Lack of adequate crosswalks at intersections', 'Lack of crossing guards at intersections', "My health condition", 'My own personal preference', 'Visually unappealing'], 
    'no_bike_reason': ['No - I bicycle a lot', 'I live too far to bicycle', 'I do not like to bicycle', "I don't have time to bicycle", 'Fear of dangerous driving', 'Lack of adequate bike lanes', 'My health condition', 'My own personal preference', 'Visually unappealing'],
    'drive_reason': ['No - I do not drive, or prefer not to drive', "I don't have time to walk or bicycle", 'Safety concerns with walking', 'Safety concerns with bicycling', 'My own health condition', 'My own personal preference']
}

# remember that there was also an 'other' field where users could enter custom answers... we'll deal with that later.

# %% [markdown]
# ## Fix the mistake we made splitting these columns
# In the `cleanup.ipynb` notebook, we split up columns with multiple answer options into multiple columns, such as `child_drive_reason_0`, `child_drive_reason1`, etc.  Merge them back together here.

# %%
# loop through each question title
for q in multiple_answer_options.keys():
    column_list = []
    for i in range(10):
        column_name = q + '_' + str(i) #auto-generate numbered column name
        if column_name in df.columns:
            column_list.append(column_name)
    if len(column_list) > 0:
        # create a new column with all answers comma-separated
        df[q] = df[column_list].apply(lambda x: ', '.join(x.fillna('').map(str)), axis=1)
        df[q] = df[q].str.strip(', ')
        
        # delete the old numbered columns
        df = df.drop(column_list, axis=1)        
df.columns
# Out:
# Index(['date', 'neighborhood', 'demographic', 'child_bus_freq',
#        'child_bike_freq', 'child_driven_freq', 'child_drive_freq',
#        'child_walk_freq', 'walk_freq', 'bike_freq', 'bikes_on_sidewalk',
#        'self_jog_frequency', 'commutes', 'child_self_school',
#        'child_self_bus_freq', 'child_self_bike_freq', 'child_self_driven_freq',
#        'child_self_drive_freq', 'child_self_walk_freq', 'child_self_commutes',
#        'child_self_has_children', 'commuter_distance', 'commuter_type',
#        'commuter_walk_to_station_freq', 'commuter_bike_to_station_freq',
#        'commuter_drive_to_station_freq', 'commuter_carpool_to_station_freq',
#        'commuter_driven_to_station_freq', 'commuter_bus_to_station_freq',
#        'feelings', 'problem_areas', 'drivers_are_safe', 'bicyclists_are_safe',
#        'suggested_improvements', 'additional_comments', 'owns_business',
#        'business_type', 'business_space', 'business_pedestrian_synergy',
#        'business_bicyclists_synergy', 'business_bike_rack_interest',
#        'business_promotion_interest', 'business_additional_comments',
#        'final_comments', 'contact_interest', 'wants_pdf', 'problem_tags',
#        'suggestion_tags', 'schools', 'child_drive_reason',
#        'child_no_walk_reason', 'child_no_bike_reason', 'no_walk_reason',
#        'no_bike_reason', 'drive_reason'],
#       dtype='object')

# %% [markdown]
# ## Add in the tagging data
# Tagging is done by the data analyst, and is assumed to be correct.  From here on, for simplicity, it will from here be stored and analyzed the same as if tags had been a question with multiple answer options with the most popular tags being treated as the answer options.

# %%
#add the most popular complaint tags to the dictionary of questions and their answer options
multiple_answer_options['problem_tags'] = [ 'speeding', 'missing sidewalks', 'cpa', 'sidewalk condition', 'aggressive driving', 'driver awareness', 's riverside', '129', 'maple', 'cyclists breaking rules', 'cleveland', 'road surface', 'municipal place', 'missing crosswalks', 'bushes on sidewalk', 'grand', 'narrow roads', 'mt airy', 'shoprite', 'benedict', 'five corners', 'van wyck', 'dummy light', 'crossing guard', 'gottwald circle', 'n riverside', 'poor lighting', 'croton commons', 'truesdale', 'hmb trail', 'cet', 'on-street parking', 'old post n', 'olcott', 'old post s', 'morningside' ]

#add the most popular suggestion tags to the dictionary of questions and their answer options
multiple_answer_options['suggestion_tags'] = [ 'bike lanes', 'more sidewalks', 'enforce speed', 'maintain sidewalks', 'reduce speed', 'educate cyclists', 'more crosswalks', 'speed bumps', 'no bike lanes', 'maintain crosswalks', 'enforce crosswalks', 'sidewalk on mt airy s', 'reduce on-street parking', 'more traffic lights', 'better lighting', 'more stop signs', 'dedicated pedestrian walk signals', 'more signs', 'improve route 9 access', 'educate pedestrians', 'outlaw cycling', 'enforce trimming of bushes', 'speed cameras', 'parking on one side only', 'bike racks', 'traffic calming', 'speed indicator signs' ]

# %% [markdown]
# ## Limit to just the multiple select columns
# For debugging

# %%
column_list = list(multiple_answer_options.keys())
df = df[column_list]
df = df.fillna('')
df.sample(n=10) #random sample of rows
# Out:
#        schools                                 child_drive_reason  \
# 116   CET, PVC                                  Kids running late
# 268
# 469
# 130  PVC, CHHS                        Our own personal preference
# 285
# 76         CET       No - we do not drive, or prefer not to drive
# 155
# 537  PVC, CHHS  Only in times of bad weather as Mt. Airy is no...
# 174
# 339
#
#                child_no_walk_reason  \
# 116      We don't have time to walk
# 268
# 469
# 130  My child does not like to walk
# 285
# 76        Fear of dangerous driving
# 155
# 537            No - they walk a lot
# 174
# 339
#
#                                   child_no_bike_reason  \
# 116  Fear of dangerous driving, Lack of adequate bi...
# 268
# 469
# 130                        Our own personal preference
# 285
# 76                           Fear of dangerous driving
# 155
# 537                        Our own personal preference
# 174
# 339
#
#                                         no_walk_reason  \
# 116  My health condition, My own personal preferenc...
# 268                         My own personal preference
# 469                                  No - I walk a lot
# 130                             Timing, need more time
# 285                                  No - I walk a lot
# 76                          My own personal preference
# 155                          I don't have time to walk
# 537                                  No - I walk a lot
# 174                         My own personal preference
# 339
#
#                                         no_bike_reason  \
# 116                       I don't have time to bicycle
# 268                                My health condition
# 469                               No - I bicycle a lot
# 130  Timing I am in a rush and I have a nice bike t...
# 285                        Lack of adequate bike lanes
# 76                            I do not like to bicycle
# 155                          Fear of dangerous driving
# 537                           I do not like to bicycle
# 174  Hazards on the road: debris, uneven surfaces etc.
# 339
#
#                                           drive_reason  \
# 116                  My own personal preference, Hills
# 268  Safety concerns with bicycling, My own persona...
# 469                     Safety concerns with bicycling
# 130                       Timing and usually in a rush
# 285  No - I do not drive, or prefer not to drive, C...
# 76                          My own personal preference
# 155               I don't have time to walk or bicycle
# 537                       Safety concerns with walking
# 174                         My own personal preference
# 339
#
#                                           problem_tags  \
# 116                               municipal place, cpa
# 268  crossing guard,missing curbs,sidewalk conditio...
# 469            s riverside,benedict,sidewalk condition
# 130                                              taxes
# 285  n riverside,missing crosswalks,bank st,missing...
# 76                                      speeding,maple
# 155
# 537                         missing sidewalks, mt airy
# 174  gottwald circle,cleveland,road surface,s river...
# 339  bushes on sidewalk,sidewalk condition,grand,mu...
#
#                                        suggestion_tags
# 116                  improve route 9 access,bike lanes
# 268           educate cyclists,retrain crossing guards
# 469                      maintain sidewalks,bike lanes
# 130                                        lower taxes
# 285  maintain sidewalks,more crosswalks,more street...
# 76                         enforce speed, reduce speed
# 155                                 maintain sidewalks
# 537  more signs, sidewalk on mt airy s, more sidewalks
# 174  parking on one side only,reduce on-street park...
# 339                  more sidewalks,maintain sidewalks

# %% [markdown]
# ## Remove commas from any given answer option so we can later split by comma cleanly

# %%
# loop through all questions that allow more than one answer
for question, answer_list in multiple_answer_options.items():
    # loop through every answer in the answer list for this question
    for answer in answer_list:
        # remove the commas, from each answer, if any
        if ',' in answer:
            # update the answers with a cleaned version
            df[question] = df[question].str.replace(answer, answer.replace(',', '') )
            
    # remove commas from the list of answers in the question/answer dictionary
    multiple_answer_options[question] = [answer.replace(',' , '') for answer in answer_list]

# show the cleaned up answer options
#multiple_answer_options

# %% [markdown]
# ## Tally answers
# Indicate which users selected which answer options, and put any freeform text answers that users entered by clicking the 'other' option in Google Forms into '_other' columns.

# %%
def categorize_answers(response, question, answer_list):    
    """
    Takes a given set of responses to a multi-select question, and puts them into a well-formated Series of dummy values.
    
    @param response A list of the user's responses to this question
    @param question The title of the question (these are codes)
    @param answer_list A list of the answer options that were presented to the user in the Google Form
    """
    
    # set up some lists that we will use to collect responses as dummy values
    indices = [] # will contain the text of the answer option that the user selected
    values = [] # will contain dummy values (1s) for each answer option the user selected, NaNs otherwise.
    
    # skip any nan or blank values
    if str(response) != 'nan' and type(answer_list) != float and type(question) != float and type(response) != float:
        #display(question + " - " + str(response))
        for answer_option in response:
            answer_option = answer_option.strip() # remove any leading/trailing whitespace
            if answer_option in answer_list and question + '_' + answer_option not in indices:
                indices.append(question + '_' + answer_option)
                values.append(1)
            elif answer_option.strip() != '' and question + '_' + 'other' not in indices:
                indices.append(question + '_' + 'other')
                values.append(answer_option)
    
        # put it all into a pandas Series
        response = pd.Series(values,index=indices).fillna(0).astype(str)
        
    return response

# slice up answers by comma and give each its own column
df2 = pd.DataFrame() # build a new dataframe from scratch

# loop through each question/answer item
for question, answer_list in multiple_answer_options.items():
    # get a new dataframe with the questions as indexes and the valuess as dummy values indicating user selections
    d = df[question].str.split(',\s*').apply(categorize_answers, question=question, answer_list=answer_list)
    df2 = df2.append(d) # append this as a row to the new dataframe

# show the new dataframe
df2.sample(n=10) #random sample of rows
# Out:
#     child_drive_reason_Lack of available busing where we live  \
# 447                                                NaN
# 504                                                NaN
# 111                                                NaN
# 11                                                 NaN
# 0                                                  NaN
# 411                                                NaN
# 485                                                NaN
# 231                                                NaN
# 307                                                NaN
# 53                                                 NaN
#
#     child_drive_reason_My child's health condition  \
# 447                                            NaN
# 504                                            NaN
# 111                                            NaN
# 11                                             NaN
# 0                                              NaN
# 411                                            NaN
# 485                                            NaN
# 231                                            NaN
# 307                                            NaN
# 53                                             NaN
#
#     child_drive_reason_No - we do not drive or prefer not to drive  \
# 447                                                NaN
# 504                                                NaN
# 111                                                NaN
# 11                                                 NaN
# 0                                                  NaN
# 411                                                NaN
# 485                                                NaN
# 231                                                NaN
# 307                                                NaN
# 53                                                 NaN
#
#     child_drive_reason_Our own personal preference  \
# 447                                            NaN
# 504                                            NaN
# 111                                            NaN
# 11                                             NaN
# 0                                              NaN
# 411                                            NaN
# 485                                            NaN
# 231                                            NaN
# 307                                            NaN
# 53                                             NaN
#
#     child_drive_reason_Safety concerns with bicycling  \
# 447                                               NaN
# 504                                               NaN
# 111                                               NaN
# 11                                                NaN
# 0                                                 NaN
# 411                                               NaN
# 485                                               NaN
# 231                                               NaN
# 307                                               NaN
# 53                                                NaN
#
#     child_drive_reason_Safety concerns with buses  \
# 447                                           NaN
# 504                                           NaN
# 111                                           NaN
# 11                                            NaN
# 0                                             NaN
# 411                                           NaN
# 485                                           NaN
# 231                                           NaN
# 307                                           NaN
# 53                                            NaN
#
#     child_drive_reason_Safety concerns with walking  \
# 447                                             NaN
# 504                                             NaN
# 111                                             NaN
# 11                                              NaN
# 0                                               NaN
# 411                                             NaN
# 485                                             NaN
# 231                                             NaN
# 307                                             NaN
# 53                                              NaN
#
#     child_drive_reason_The bus schedule does not match our schedule  \
# 447                                                NaN
# 504                                                NaN
# 111                                                NaN
# 11                                                 NaN
# 0                                                  NaN
# 411                                                NaN
# 485                                                NaN
# 231                                                NaN
# 307                                                NaN
# 53                                                 NaN
#
#     child_drive_reason_other child_no_bike_reason_Fear of dangerous driving  \
# 447                      NaN                                            NaN
# 504                      NaN                                            NaN
# 111                      NaN                                            NaN
# 11                       NaN                                            NaN
# 0                        NaN                                            NaN
# 411                      NaN                                              1
# 485                      NaN                                            NaN
# 231                      NaN                                            NaN
# 307                      NaN                                            NaN
# 53                       NaN                                            NaN
#
#                   ...               suggestion_tags_other  \
# 447               ...                                 NaN
# 504               ...                                 NaN
# 111               ...                                 NaN
# 11                ...                                 NaN
# 0                 ...                                 NaN
# 411               ...                                 NaN
# 485               ...                                 NaN
# 231               ...                                 NaN
# 307               ...                                 NaN
# 53                ...                                 NaN
#
#     suggestion_tags_outlaw cycling suggestion_tags_parking on one side only  \
# 447                            NaN                                      NaN
# 504                            NaN                                      NaN
# 111                            NaN                                      NaN
# 11                             NaN                                      NaN
# 0                              NaN                                      NaN
# 411                            NaN                                      NaN
# 485                            NaN                                      NaN
# 231                            NaN                                      NaN
# 307                            NaN                                      NaN
# 53                             NaN                                      NaN
#
#     suggestion_tags_reduce on-street parking suggestion_tags_reduce speed  \
# 447                                      NaN                          NaN
# 504                                      NaN                          NaN
# 111                                      NaN                          NaN
# 11                                       NaN                          NaN
# 0                                        NaN                          NaN
# 411                                      NaN                          NaN
# 485                                      NaN                          NaN
# 231                                      NaN                          NaN
# 307                                      NaN                          NaN
# 53                                       NaN                          NaN
#
#     suggestion_tags_sidewalk on mt airy s suggestion_tags_speed bumps  \
# 447                                   NaN                         NaN
# 504                                   NaN                         NaN
# 111                                   NaN                         NaN
# 11                                    NaN                         NaN
# 0                                     NaN                         NaN
# 411                                   NaN                         NaN
# 485                                   NaN                         NaN
# 231                                   NaN                         NaN
# 307                                   NaN                         NaN
# 53                                    NaN                         NaN
#
#     suggestion_tags_speed cameras suggestion_tags_speed indicator signs  \
# 447                           NaN                                   NaN
# 504                           NaN                                   NaN
# 111                           NaN                                   NaN
# 11                            NaN                                   NaN
# 0                             NaN                                   NaN
# 411                           NaN                                   NaN
# 485                           NaN                                   NaN
# 231                           NaN                                   NaN
# 307                           NaN                                   NaN
# 53                            NaN                                   NaN
#
#     suggestion_tags_traffic calming
# 447                             NaN
# 504                             NaN
# 111                             NaN
# 11                              NaN
# 0                               NaN
# 411                             NaN
# 485                             NaN
# 231                             NaN
# 307                             NaN
# 53                              NaN
#
# [10 rows x 130 columns]

# %% [markdown]
# ## Convert values to ints or booleans, where possible
# Most columns contain NaNs or 1s.  NaNs are converted to 0s then to booleans, if desired.  Integer dummy values are perhaps more useful so we can take counts of responses by adding the ints up.  The 'other' columns contain text and are left alone.

# %%
# loop through each column
for col in df2.columns:
    try:
        # try to convert to int
        df2[col] = df2[col].fillna(0).astype(int)#.astype(bool)
    except:
        # if this column contains text, skip...
        continue

# %% [markdown]
# ## Group rows by 'id' so there is one row for each respondent

# %%
# add up all values in each column to get a full set of values or each id
# this loses the 'other' columns, since they are not numeric
df3 = df2.groupby(df2.index).sum()

# show the new grouped data... note that it is missing the 'other' fields... more on that later
df3.sample(n=10) #random sample of rows
# Out:
#      child_drive_reason_Lack of available busing where we live  \
# 25                                                   0
# 74                                                   0
# 132                                                  0
# 432                                                  0
# 304                                                  0
# 411                                                  0
# 174                                                  0
# 360                                                  0
# 94                                                   0
# 364                                                  0
#
#      child_drive_reason_My child's health condition  \
# 25                                                0
# 74                                                0
# 132                                               0
# 432                                               0
# 304                                               0
# 411                                               0
# 174                                               0
# 360                                               0
# 94                                                0
# 364                                               0
#
#      child_drive_reason_No - we do not drive or prefer not to drive  \
# 25                                                   1
# 74                                                   0
# 132                                                  0
# 432                                                  1
# 304                                                  0
# 411                                                  0
# 174                                                  0
# 360                                                  0
# 94                                                   0
# 364                                                  0
#
#      child_drive_reason_Our own personal preference  \
# 25                                                0
# 74                                                0
# 132                                               0
# 432                                               0
# 304                                               0
# 411                                               0
# 174                                               0
# 360                                               0
# 94                                                0
# 364                                               0
#
#      child_drive_reason_Safety concerns with bicycling  \
# 25                                                   0
# 74                                                   0
# 132                                                  0
# 432                                                  0
# 304                                                  0
# 411                                                  0
# 174                                                  0
# 360                                                  0
# 94                                                   0
# 364                                                  0
#
#      child_drive_reason_Safety concerns with buses  \
# 25                                               0
# 74                                               0
# 132                                              0
# 432                                              0
# 304                                              0
# 411                                              0
# 174                                              0
# 360                                              0
# 94                                               0
# 364                                              0
#
#      child_drive_reason_Safety concerns with walking  \
# 25                                                 0
# 74                                                 0
# 132                                                0
# 432                                                0
# 304                                                0
# 411                                                0
# 174                                                0
# 360                                                0
# 94                                                 0
# 364                                                0
#
#      child_drive_reason_The bus schedule does not match our schedule  \
# 25                                                   0
# 74                                                   0
# 132                                                  0
# 432                                                  0
# 304                                                  0
# 411                                                  0
# 174                                                  0
# 360                                                  0
# 94                                                   0
# 364                                                  0
#
#      child_no_bike_reason_Fear of dangerous driving  \
# 25                                                0
# 74                                                0
# 132                                               0
# 432                                               0
# 304                                               0
# 411                                               1
# 174                                               0
# 360                                               0
# 94                                                0
# 364                                               0
#
#      child_no_bike_reason_Hills               ...                 \
# 25                            0               ...
# 74                            0               ...
# 132                           0               ...
# 432                           0               ...
# 304                           0               ...
# 411                           0               ...
# 174                           0               ...
# 360                           0               ...
# 94                            0               ...
# 364                           0               ...
#
#      suggestion_tags_no bike lanes  suggestion_tags_outlaw cycling  \
# 25                               0                               0
# 74                               0                               0
# 132                              0                               0
# 432                              0                               0
# 304                              0                               0
# 411                              0                               0
# 174                              1                               0
# 360                              0                               0
# 94                               1                               0
# 364                              0                               0
#
#      suggestion_tags_parking on one side only  \
# 25                                          0
# 74                                          0
# 132                                         0
# 432                                         0
# 304                                         0
# 411                                         0
# 174                                         1
# 360                                         0
# 94                                          0
# 364                                         0
#
#      suggestion_tags_reduce on-street parking  suggestion_tags_reduce speed  \
# 25                                          0                             0
# 74                                          0                             0
# 132                                         0                             0
# 432                                         0                             0
# 304                                         0                             1
# 411                                         0                             1
# 174                                         1                             0
# 360                                         0                             0
# 94                                          0                             0
# 364                                         0                             0
#
#      suggestion_tags_sidewalk on mt airy s  suggestion_tags_speed bumps  \
# 25                                       0                            0
# 74                                       0                            0
# 132                                      0                            0
# 432                                      0                            1
# 304                                      0                            0
# 411                                      0                            0
# 174                                      0                            0
# 360                                      0                            0
# 94                                       0                            0
# 364                                      0                            0
#
#      suggestion_tags_speed cameras  suggestion_tags_speed indicator signs  \
# 25                               0                                      0
# 74                               0                                      0
# 132                              0                                      0
# 432                              0                                      0
# 304                              0                                      0
# 411                              0                                      0
# 174                              0                                      0
# 360                              0                                      0
# 94                               0                                      0
# 364                              0                                      0
#
#      suggestion_tags_traffic calming
# 25                                 0
# 74                                 0
# 132                                0
# 432                                0
# 304                                0
# 411                                0
# 174                                0
# 360                                0
# 94                                 0
# 364                                0
#
# [10 rows x 121 columns]

# %% [markdown]
# ## Combine the selected answer options with the 'other' responses users gave

# %%
# loop through all questions
for question, answer_options in multiple_answer_options.items():
    # get a dataframe of just the 'other' answers to this question
    other_df = df2[pd.notnull(df2[question + '_other'])][question + '_other'].to_frame()
    # concatenate those responses to the original dataframe
    df3 = df3.join(other_df)
    
# show the data
df3.sample(n=10) #random sample of rows
# Out:
#      child_drive_reason_Lack of available busing where we live  \
# 337                                                  0
# 547                                                  0
# 52                                                   0
# 437                                                  0
# 446                                                  0
# 238                                                  0
# 257                                                  0
# 392                                                  0
# 240                                                  0
# 132                                                  0
#
#      child_drive_reason_My child's health condition  \
# 337                                               0
# 547                                               0
# 52                                                0
# 437                                               0
# 446                                               0
# 238                                               0
# 257                                               0
# 392                                               0
# 240                                               0
# 132                                               0
#
#      child_drive_reason_No - we do not drive or prefer not to drive  \
# 337                                                  0
# 547                                                  0
# 52                                                   0
# 437                                                  0
# 446                                                  0
# 238                                                  0
# 257                                                  0
# 392                                                  0
# 240                                                  0
# 132                                                  0
#
#      child_drive_reason_Our own personal preference  \
# 337                                               0
# 547                                               0
# 52                                                0
# 437                                               0
# 446                                               0
# 238                                               1
# 257                                               0
# 392                                               1
# 240                                               0
# 132                                               0
#
#      child_drive_reason_Safety concerns with bicycling  \
# 337                                                  0
# 547                                                  0
# 52                                                   0
# 437                                                  0
# 446                                                  0
# 238                                                  0
# 257                                                  0
# 392                                                  0
# 240                                                  0
# 132                                                  0
#
#      child_drive_reason_Safety concerns with buses  \
# 337                                              0
# 547                                              0
# 52                                               0
# 437                                              0
# 446                                              0
# 238                                              0
# 257                                              0
# 392                                              0
# 240                                              0
# 132                                              0
#
#      child_drive_reason_Safety concerns with walking  \
# 337                                                0
# 547                                                0
# 52                                                 0
# 437                                                0
# 446                                                0
# 238                                                0
# 257                                                0
# 392                                                0
# 240                                                0
# 132                                                0
#
#      child_drive_reason_The bus schedule does not match our schedule  \
# 337                                                  0
# 547                                                  1
# 52                                                   0
# 437                                                  0
# 446                                                  0
# 238                                                  0
# 257                                                  0
# 392                                                  0
# 240                                                  0
# 132                                                  0
#
#      child_no_bike_reason_Fear of dangerous driving  \
# 337                                               0
# 547                                               1
# 52                                                0
# 437                                               0
# 446                                               0
# 238                                               0
# 257                                               0
# 392                                               0
# 240                                               0
# 132                                               0
#
#      child_no_bike_reason_Hills                   ...                     \
# 337                           0                   ...
# 547                           0                   ...
# 52                            0                   ...
# 437                           0                   ...
# 446                           1                   ...
# 238                           0                   ...
# 257                           0                   ...
# 392                           0                   ...
# 240                           0                   ...
# 132                           0                   ...
#
#      suggestion_tags_traffic calming                      schools_other  \
# 337                                0                                NaN
# 547                                0                                NaN
# 52                                 0                                NaN
# 437                                0                                NaN
# 446                                0                                NaN
# 238                                0                                NaN
# 257                                0  Currently pre-school but soon CET
# 392                                0                                NaN
# 240                                0                                NaN
# 132                                0                                NaN
#
#                               child_drive_reason_other  \
# 337                                                NaN
# 547  CET has 7:35-7:40 Chorus and Band practice.  T...
# 52                                                 NaN
# 437                                                NaN
# 446                                        Bad weather
# 238                                                NaN
# 257                      Her pre-school is out of town
# 392                                                NaN
# 240                                                NaN
# 132                                                NaN
#
#                             child_no_walk_reason_other  \
# 337                                                NaN
# 547                                               Well
# 52                                                 NaN
# 437                                                NaN
# 446                                                NaN
# 238  Timing or Bc of carrying too many school supplies
# 257                                              Again
# 392                                                NaN
# 240                                                NaN
# 132                                                NaN
#
#            child_no_bike_reason_other  no_walk_reason_other  \
# 337                               NaN                   NaN
# 547  She still rides on the side walk                   NaN
# 52                                NaN                   NaN
# 437                               NaN                   NaN
# 446                               NaN                   NaN
# 238                               NaN                   NaN
# 257        She's just not biking yet.                   NaN
# 392                               NaN                   NaN
# 240                               NaN                   NaN
# 132                               NaN                   NaN
#
#       no_bike_reason_other                drive_reason_other  \
# 337                    NaN                               NaN
# 547     I don't own a bike                               NaN
# 52                     NaN                               NaN
# 437                    NaN  Picking up groceries or at night
# 446                    NaN                               NaN
# 238                    NaN                               NaN
# 257  Can't bike with kiddo                               NaN
# 392                    NaN                               NaN
# 240                    NaN                               NaN
# 132                    NaN                  Sometimes I walk
#
#              problem_tags_other                    suggestion_tags_other
# 337                       wells                       make wells one way
# 547         bushes on sidewalks                                      NaN
# 52                     gerstein  extend croton landing path to peekskill
# 437                         NaN                                      NaN
# 446                         NaN                       sidewalk condition
# 238                         NaN                                      NaN
# 257                    gerstein                                      NaN
# 392                         NaN                                      NaN
# 240  cyclists at croton landing                                      NaN
# 132                         NaN                                      NaN
#
# [10 rows x 130 columns]

# %% [markdown]
# ## Order the columns alphabetically
# So it looks a bit more orderly

# %%
column_names = df3.columns.sort_values()
df3 = df3[column_names]
df3.sample(n=10) #random sample of rows
# Out:
#      child_drive_reason_Lack of available busing where we live  \
# 271                                                  0
# 219                                                  0
# 267                                                  0
# 70                                                   0
# 322                                                  0
# 509                                                  0
# 153                                                  0
# 80                                                   0
# 19                                                   0
# 15                                                   0
#
#      child_drive_reason_My child's health condition  \
# 271                                               0
# 219                                               0
# 267                                               0
# 70                                                0
# 322                                               0
# 509                                               0
# 153                                               0
# 80                                                0
# 19                                                0
# 15                                                0
#
#      child_drive_reason_No - we do not drive or prefer not to drive  \
# 271                                                  0
# 219                                                  1
# 267                                                  0
# 70                                                   1
# 322                                                  0
# 509                                                  1
# 153                                                  0
# 80                                                   0
# 19                                                   0
# 15                                                   0
#
#      child_drive_reason_Our own personal preference  \
# 271                                               0
# 219                                               0
# 267                                               0
# 70                                                0
# 322                                               0
# 509                                               0
# 153                                               0
# 80                                                0
# 19                                                0
# 15                                                0
#
#      child_drive_reason_Safety concerns with bicycling  \
# 271                                                  0
# 219                                                  0
# 267                                                  0
# 70                                                   0
# 322                                                  0
# 509                                                  0
# 153                                                  0
# 80                                                   0
# 19                                                   0
# 15                                                   1
#
#      child_drive_reason_Safety concerns with buses  \
# 271                                              0
# 219                                              0
# 267                                              0
# 70                                               0
# 322                                              0
# 509                                              0
# 153                                              0
# 80                                               0
# 19                                               0
# 15                                               0
#
#      child_drive_reason_Safety concerns with walking  \
# 271                                                0
# 219                                                0
# 267                                                0
# 70                                                 0
# 322                                                0
# 509                                                0
# 153                                                0
# 80                                                 0
# 19                                                 0
# 15                                                 0
#
#      child_drive_reason_The bus schedule does not match our schedule  \
# 271                                                  0
# 219                                                  0
# 267                                                  0
# 70                                                   0
# 322                                                  0
# 509                                                  0
# 153                                                  0
# 80                                                   0
# 19                                                   0
# 15                                                   0
#
#              child_drive_reason_other  \
# 271                               NaN
# 219                               NaN
# 267                               NaN
# 70                                NaN
# 322  G Days and High school schedule.
# 509                               NaN
# 153                               NaN
# 80                                NaN
# 19                                NaN
# 15                                NaN
#
#      child_no_bike_reason_Fear of dangerous driving  \
# 271                                               0
# 219                                               0
# 267                                               0
# 70                                                1
# 322                                               1
# 509                                               0
# 153                                               0
# 80                                                0
# 19                                                0
# 15                                                0
#
#                   ...                            suggestion_tags_other  \
# 271               ...                                              NaN
# 219               ...                                              NaN
# 267               ...                          5 way stop on mt airy s
# 70                ...                                              NaN
# 322               ...                open gate on highland during rush
# 509               ...                                              NaN
# 153               ...                                              NaN
# 80                ...                                              NaN
# 19                ...                                              NaN
# 15                ...                                              NaN
#
#      suggestion_tags_outlaw cycling  suggestion_tags_parking on one side only  \
# 271                               0                                         0
# 219                               0                                         0
# 267                               0                                         0
# 70                                0                                         0
# 322                               0                                         0
# 509                               0                                         0
# 153                               0                                         0
# 80                                0                                         1
# 19                                0                                         0
# 15                                0                                         0
#
#      suggestion_tags_reduce on-street parking  suggestion_tags_reduce speed  \
# 271                                         0                             0
# 219                                         0                             0
# 267                                         0                             0
# 70                                          0                             0
# 322                                         0                             0
# 509                                         0                             0
# 153                                         0                             0
# 80                                          0                             0
# 19                                          0                             0
# 15                                          0                             0
#
#      suggestion_tags_sidewalk on mt airy s  suggestion_tags_speed bumps  \
# 271                                      0                            0
# 219                                      0                            0
# 267                                      0                            0
# 70                                       0                            1
# 322                                      1                            0
# 509                                      0                            0
# 153                                      0                            0
# 80                                       0                            0
# 19                                       0                            0
# 15                                       0                            0
#
#      suggestion_tags_speed cameras  suggestion_tags_speed indicator signs  \
# 271                              0                                      0
# 219                              0                                      0
# 267                              0                                      0
# 70                               0                                      0
# 322                              0                                      0
# 509                              0                                      0
# 153                              0                                      0
# 80                               0                                      0
# 19                               0                                      0
# 15                               0                                      0
#
#     suggestion_tags_traffic calming
# 271                               0
# 219                               0
# 267                               0
# 70                                0
# 322                               0
# 509                               0
# 153                               0
# 80                                0
# 19                                0
# 15                                0
#
# [10 rows x 130 columns]

# %% [markdown]
# ## Merge with remaining data

# %%
# load up the original data from scratch again
df = pd.read_csv('responses_scrubbed_tagged.csv', index_col=None, parse_dates=['date'])

# merge the new columns with the old dataframe based on the indexes of each row
df_complete = pd.merge(df, df3, right_index=True, left_index=True)

df_complete.sample(n=10) #random sample of rows
# Out:
#                    date         neighborhood               demographic  \
# 30  2019-07-03 15:42:44  Old Post Road North  Adult without school kid
# 255 2019-07-04 08:34:38               Harmon     Adult with school kid
# 206 2019-07-03 20:52:31        Upper Village                       NaN
# 54  2019-07-03 15:53:54        Upper Village  Adult without school kid
# 41  2019-07-03 15:47:08               Harmon  Adult without school kid
# 375 2019-07-07 20:01:09        Upper Village     Adult with school kid
# 453 2019-07-10 13:59:38        Upper Village  Adult without school kid
# 248 2019-07-04 07:21:05  Old Post Road North                    Senior
# 61  2019-07-03 15:56:08  Old Post Road North  Adult without school kid
# 494 2019-07-14 18:51:41               Harmon  Adult without school kid
#
#                      child_bus_freq  \
# 30                              NaN
# 255  Every day, or almost every day
# 206                             NaN
# 54                              NaN
# 41                              NaN
# 375  Every day, or almost every day
# 453                             NaN
# 248                             NaN
# 61                              NaN
# 494                             NaN
#
#                                  child_bike_freq    child_driven_freq  \
# 30                                           NaN                  NaN
# 255          Rarely or never - for other reasons  Once every few days
# 206                                          NaN                  NaN
# 54                                           NaN                  NaN
# 41                                           NaN                  NaN
# 375  Rarely or never - my children are too young      Rarely or never
# 453                                          NaN                  NaN
# 248                                          NaN                  NaN
# 61                                           NaN                  NaN
# 494                                          NaN                  NaN
#
#                                 child_drive_freq  \
# 30                                           NaN
# 255  Rarely or never - my children are too young
# 206                                          NaN
# 54                                           NaN
# 41                                           NaN
# 375  Rarely or never - my children are too young
# 453                                          NaN
# 248                                          NaN
# 61                                           NaN
# 494                                          NaN
#
#                                  child_walk_freq            walk_freq  \
# 30                                           NaN                  NaN
# 255                              Once in a while  Once every few days
# 206                                          NaN  Once every few days
# 54                                           NaN  Once every few days
# 41                                           NaN  Once every few days
# 375  Rarely or never - my children are too young  Once every few days
# 453                                          NaN      Rarely or never
# 248                                          NaN  Once every few days
# 61                                           NaN      Rarely or never
# 494                                          NaN  Once every few days
#
#            bike_freq               ...                \
# 30               NaN               ...
# 255  Once in a while               ...
# 206  Rarely or never               ...
# 54   Rarely or never               ...
# 41   Rarely or never               ...
# 375  Rarely or never               ...
# 453  Rarely or never               ...
# 248  Rarely or never               ...
# 61   Rarely or never               ...
# 494  Rarely or never               ...
#
#                         suggestion_tags_other suggestion_tags_outlaw cycling  \
# 30                                        NaN                              0
# 255                                       NaN                              0
# 206                           reduce num cars                              0
# 54                                        NaN                              0
# 41   stop signs on lexington near sunset park                              0
# 375                                bike share                              0
# 453                                       NaN                              0
# 248                                       NaN                              0
# 61                                        NaN                              0
# 494                                       NaN                              0
#
#     suggestion_tags_parking on one side only  \
# 30                                         0
# 255                                        0
# 206                                        0
# 54                                         0
# 41                                         0
# 375                                        0
# 453                                        0
# 248                                        0
# 61                                         0
# 494                                        0
#
#     suggestion_tags_reduce on-street parking suggestion_tags_reduce speed  \
# 30                                         0                            0
# 255                                        0                            0
# 206                                        0                            0
# 54                                         0                            0
# 41                                         0                            0
# 375                                        0                            0
# 453                                        0                            0
# 248                                        0                            0
# 61                                         0                            0
# 494                                        0                            0
#
#     suggestion_tags_sidewalk on mt airy s suggestion_tags_speed bumps  \
# 30                                      0                           0
# 255                                     0                           0
# 206                                     0                           0
# 54                                      0                           0
# 41                                      0                           0
# 375                                     0                           0
# 453                                     0                           0
# 248                                     0                           0
# 61                                      0                           0
# 494                                     0                           0
#
#     suggestion_tags_speed cameras suggestion_tags_speed indicator signs  \
# 30                              0                                     0
# 255                             0                                     0
# 206                             0                                     0
# 54                              0                                     0
# 41                              0                                     0
# 375                             0                                     0
# 453                             0                                     0
# 248                             0                                     0
# 61                              0                                     0
# 494                             0                                     0
#
#     suggestion_tags_traffic calming
# 30                                0
# 255                               0
# 206                               0
# 54                                0
# 41                                0
# 375                               0
# 453                               0
# 248                               0
# 61                                0
# 494                               0
#
# [10 rows x 210 columns]

# %% [markdown]
# ## Save to new CSV file

# %%
df_complete.to_csv('responses_complete.csv', index=False)

# %% [markdown]
# ## Done!
