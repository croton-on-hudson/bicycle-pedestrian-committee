# %% [markdown]
# # Multiple answer cleanup
# Attempt at dealing with fields that contain comma-separated lists of answers from questions with multiple-select answer options that also allow respondents to enter their own 'other' answer.
#
# This notebook assumes the file named `responses_scrubbed_tagged.csv` has already been created by running the notebook named `free_text_tagging.ipynb`.  This notebook then creates a new data file called `responses_complete.csv` which has the complete set of final data.

# %%
import pandas as pd
import numpy as np
from IPython.display import display, Markdown, Latex

# %% [markdown]
# ## Load tagged data set
# This notebook assumes you have already scrubbed and tagged the data using the `free_text_tagging.ipynb` notebook first.

# %%
df = pd.read_csv('responses_scrubbed_tagged.csv', index_col=None, parse_dates=['date'])
df.sample(n=10) #random sample of rows
# Out:
#                    date         neighborhood               demographic  \
# 388 2019-07-08 10:29:53        Upper Village     Adult with school kid
# 397 2019-07-08 16:58:42               Harmon     Adult with school kid
# 424 2019-07-09 13:51:38               Harmon     Adult with school kid
# 495 2019-07-14 21:51:42         Quaker Ridge  Adult without school kid
# 44  2019-07-03 15:48:29               Harmon     Adult with school kid
# 91  2019-07-03 16:19:49               Harmon     Adult with school kid
# 229 2019-07-03 23:08:46          Sunset Park               College kid
# 302 2019-07-04 16:45:45  Old Post Road North  Adult without school kid
# 140 2019-07-03 17:26:59     Albany Post Road                    Senior
# 511 2019-07-18 09:46:57        Upper Village     Adult with school kid
#
#                      child_bus_freq  \
# 388                 Once in a while
# 397                 Rarely or never
# 424             Once every few days
# 495                             NaN
# 44   Every day, or almost every day
# 91                  Rarely or never
# 229                             NaN
# 302                             NaN
# 140                             NaN
# 511  Every day, or almost every day
#
#                                  child_bike_freq  \
# 388                              Once in a while
# 397          Rarely or never - for other reasons
# 424          Rarely or never - for other reasons
# 495                                          NaN
# 44   Rarely or never - my children are too young
# 91           Rarely or never - for other reasons
# 229                                          NaN
# 302                                          NaN
# 140                                          NaN
# 511  Rarely or never - my children are too young
#
#                   child_driven_freq  \
# 388                 Once in a while
# 397  Every day, or almost every day
# 424  Every day, or almost every day
# 495                             NaN
# 44                  Rarely or never
# 91   Every day, or almost every day
# 229                             NaN
# 302                             NaN
# 140                             NaN
# 511                 Rarely or never
#
#                                 child_drive_freq  \
# 388          Rarely or never - for other reasons
# 397  Rarely or never - my children are too young
# 424  Rarely or never - my children are too young
# 495                                          NaN
# 44   Rarely or never - my children are too young
# 91           Rarely or never - for other reasons
# 229                                          NaN
# 302                                          NaN
# 140                                          NaN
# 511  Rarely or never - my children are too young
#
#                                  child_walk_freq  \
# 388                              Once in a while
# 397  Rarely or never - my children are too young
# 424  Rarely or never - my children are too young
# 495                                          NaN
# 44                               Once in a while
# 91                Every day, or almost every day
# 229                                          NaN
# 302                                          NaN
# 140                                          NaN
# 511  Rarely or never - my children are too young
#
#                           walk_freq                       bike_freq  ...  \
# 388             Once every few days                 Once in a while  ...
# 397                 Once in a while                 Rarely or never  ...
# 424                 Once in a while                 Once in a while  ...
# 495                 Rarely or never                 Rarely or never  ...
# 44   Every day, or almost every day                 Rarely or never  ...
# 91   Every day, or almost every day                 Once in a while  ...
# 229                 Rarely or never  Every day, or almost every day  ...
# 302             Once every few days             Once every few days  ...
# 140                 Rarely or never                 Rarely or never  ...
# 511                 Once in a while                 Rarely or never  ...
#
#     no_bike_reason_2 no_bike_reason_3                        drive_reason_0  \
# 388              NaN              NaN          Safety concerns with walking
# 397              NaN              NaN          Safety concerns with walking
# 424              NaN              NaN  I don't have time to walk or bicycle
# 495              NaN              NaN  I don't have time to walk or bicycle
# 44               NaN              NaN          Safety concerns with walking
# 91               NaN              NaN        Safety concerns with bicycling
# 229              NaN              NaN  I don't have time to walk or bicycle
# 302              NaN              NaN            My own personal preference
# 140              NaN              NaN            My own personal preference
# 511              NaN              NaN  I don't have time to walk or bicycle
#
#                      drive_reason_1 drive_reason_2 drive_reason_3  \
# 388                             NaN            NaN            NaN
# 397  Safety concerns with bicycling            NaN            NaN
# 424                             NaN            NaN            NaN
# 495                             NaN            NaN            NaN
# 44                              NaN            NaN            NaN
# 91                              NaN            NaN            NaN
# 229                             NaN            NaN            NaN
# 302                             NaN            NaN            NaN
# 140                             NaN            NaN            NaN
# 511                             NaN            NaN            NaN
#
#     drive_reason_4 drive_reason_5  \
# 388            NaN            NaN
# 397            NaN            NaN
# 424            NaN            NaN
# 495            NaN            NaN
# 44             NaN            NaN
# 91             NaN            NaN
# 229            NaN            NaN
# 302            NaN            NaN
# 140            NaN            NaN
# 511            NaN            NaN
#
#                                           problem_tags  \
# 388  dummy light,crosswalk condition,sidewalk condi...
# 397  missing crosswalks,speeding,driver awareness,c...
# 424                                    gottwald circle
# 495                                   cpa,road surface
# 44   gottwald circle,missing sidewalks,cpa,shoprite...
# 91   missing sidewalks, cet, cleveland, five corner...
# 229  aggressive driving,driver awareness,municipal ...
# 302       pedestrians in roads,cyclists breaking rules
# 140                                       five corners
# 511                 cpa,s riverside,aggressive driving
#
#                                        suggestion_tags
# 388  pedestrian-only upper village,dedicated pedest...
# 397  better lighting,educate cyclists,more crosswal...
# 424                                    more stop signs
# 495                                                NaN
# 44   maintain crosswalks, more crosswalks, maintain...
# 91   more sidewalks,more crosswalks,better lighting...
# 229               beautify underpass on cpa,bike lanes
# 302               educate cyclists,educate pedestrians
# 140  more traffic lights,traffic light at five corners
# 511                                         bike lanes
#
# [10 rows x 80 columns]

# %% [markdown]
# ## Answer options to each question
# A dictionary containing lists of all the questions and the answer options that the user was asked to select from for each question in the Google Form.

# %%
# a dictionary of columns that contain comma-separated multiple answer options
multiple_answer_options = {
    'schools': ['CET', 'PVC', 'CHHS', 'Homeschooled'],
    'child_drive_reason': ['No - we do not drive, or prefer not to drive', 'Our own personal preference', 'Lack of available busing where we live', 'The bus schedule does not match our schedule', 'Safety concerns with buses', 'Safety concerns with walking', 'Safety concerns with bicycling', "My child's health condition"],
    'child_no_walk_reason': ['No - they walk a lot', 'My child does not like to walk', 'We live too far to walk', "We don't have time to walk", 'Fear of dangerous driving', 'Lack of adequate sidewalks', 'Lack of adequate crosswalks at busy intersections', 'Lack of crossing guards at busy intersections', "My child's health condition", 'Visually unappealing route'],
    'child_no_bike_reason': ['No - they bicycle a lot', 'My child does not like to bicycle', 'My child is too young to bicycle', 'We live too far to bicycle', 'Our own personal preference', 'Fear of dangerous driving', 'Lack of adequate bike lanes', "My child's health condition", 'Visually unappealing route', 'Hills'],
    'no_walk_reason': ['No - I walk a lot', 'I live too far to walk', 'I do not like to walk', "I don't have time to walk", 'Fear of dangerous driving', 'Lack of adequate sidewalks', 'Lack of adequate crosswalks at intersections', 'Lack of crossing guards at intersections', "My health condition", 'My own personal preference', 'Visually unappealing'], 
    'no_bike_reason': ['No - I bicycle a lot', 'I live too far to bicycle', 'I do not like to bicycle', "I don't have time to bicycle", 'Fear of dangerous driving', 'Lack of adequate bike lanes', 'My health condition', 'My own personal preference', 'Visually unappealing'],
    'drive_reason': ['No - I do not drive, or prefer not to drive', "I don't have time to walk or bicycle", 'Safety concerns with walking', 'Safety concerns with bicycling', 'My own health condition', 'My own personal preference']
}

# remember that there was also an 'other' field where users could enter custom answers... we'll deal with that later.

# %% [markdown]
# ## Fix the mistake we made splitting these columns
# In the `cleanup.ipynb` notebook, we split up columns with multiple answer options into multiple columns, such as `child_drive_reason_0`, `child_drive_reason1`, etc.  Merge them back together here.

# %%
# loop through each question title
for q in multiple_answer_options.keys():
    column_list = []
    for i in range(10):
        column_name = q + '_' + str(i) #auto-generate numbered column name
        if column_name in df.columns:
            column_list.append(column_name)
    if len(column_list) > 0:
        # create a new column with all answers comma-separated
        df[q] = df[column_list].apply(lambda x: ', '.join(x.fillna('').map(str)), axis=1)
        df[q] = df[q].str.strip(', ')
        
        # delete the old numbered columns
        df = df.drop(column_list, axis=1)        
df.columns
# Out:
# Index(['date', 'neighborhood', 'demographic', 'child_bus_freq',
#        'child_bike_freq', 'child_driven_freq', 'child_drive_freq',
#        'child_walk_freq', 'walk_freq', 'bike_freq', 'bikes_on_sidewalk',
#        'self_jog_frequency', 'commutes', 'child_self_school',
#        'child_self_bus_freq', 'child_self_bike_freq', 'child_self_driven_freq',
#        'child_self_drive_freq', 'child_self_walk_freq', 'child_self_commutes',
#        'child_self_has_children', 'commuter_distance', 'commuter_type',
#        'commuter_walk_to_station_freq', 'commuter_bike_to_station_freq',
#        'commuter_drive_to_station_freq', 'commuter_carpool_to_station_freq',
#        'commuter_driven_to_station_freq', 'commuter_bus_to_station_freq',
#        'feelings', 'problem_areas', 'drivers_are_safe', 'bicyclists_are_safe',
#        'suggested_improvements', 'additional_comments', 'owns_business',
#        'business_type', 'business_space', 'business_pedestrian_synergy',
#        'business_bicyclists_synergy', 'business_bike_rack_interest',
#        'business_promotion_interest', 'business_additional_comments',
#        'final_comments', 'contact_interest', 'wants_pdf', 'problem_tags',
#        'suggestion_tags', 'schools', 'child_drive_reason',
#        'child_no_walk_reason', 'child_no_bike_reason', 'no_walk_reason',
#        'no_bike_reason', 'drive_reason'],
#       dtype='object')

# %% [markdown]
# ## Add in the tagging data
# Tagging is done by the data analyst, and is assumed to be correct.  From here on, for simplicity, it will from here be stored and analyzed the same as if tags had been a question with multiple answer options with the most popular tags being treated as the answer options.

# %%
#add the most popular complaint tags to the dictionary of questions and their answer options
multiple_answer_options['problem_tags'] = [ 'speeding', 'missing sidewalks', 'cpa', 'sidewalk condition', 'aggressive driving', 'driver awareness', 's riverside', '129', 'maple', 'cyclists breaking rules', 'cleveland', 'road surface', 'municipal place', 'missing crosswalks', 'bushes on sidewalk', 'grand', 'narrow roads', 'mt airy', 'shoprite', 'benedict', 'five corners', 'van wyck', 'dummy light', 'crossing guard', 'gottwald circle', 'n riverside', 'poor lighting', 'croton commons', 'truesdale', 'hmb trail', 'cet', 'on-street parking', 'old post n', 'olcott', 'old post s', 'morningside' ]

#add the most popular suggestion tags to the dictionary of questions and their answer options
multiple_answer_options['suggestion_tags'] = [ 'bike lanes', 'more sidewalks', 'enforce speed', 'maintain sidewalks', 'reduce speed', 'educate cyclists', 'more crosswalks', 'speed bumps', 'no bike lanes', 'maintain crosswalks', 'enforce crosswalks', 'sidewalk on mt airy s', 'reduce on-street parking', 'more traffic lights', 'better lighting', 'more stop signs', 'dedicated pedestrian walk signals', 'more signs', 'improve route 9 access', 'educate pedestrians', 'outlaw cycling', 'enforce trimming of bushes', 'speed cameras', 'parking on one side only', 'bike racks', 'traffic calming', 'speed indicator signs' ]

# %% [markdown]
# ## Limit to just the multiple select columns
# For debugging

# %%
column_list = list(multiple_answer_options.keys())
df = df[column_list]
df = df.fillna('')
df.sample(n=10) #random sample of rows
# Out:
#                                schools  \
# 537                          PVC, CHHS
# 441                           CET, PVC
# 257  Currently pre-school but soon CET
# 485                                CET
# 94
# 160                                CET
# 45
# 161
# 188
# 491              Happy Hearts Day Care
#
#                                     child_drive_reason  \
# 537  Only in times of bad weather as Mt. Airy is no...
# 441       No - we do not drive, or prefer not to drive
# 257  Her pre-school is out of town, but our intenti...
# 485       No - we do not drive, or prefer not to drive
# 94
# 160       No - we do not drive, or prefer not to drive
# 45
# 161
# 188
# 491                       Safety concerns with walking
#
#                                   child_no_walk_reason  \
# 537                               No - they walk a lot
# 441                               No - they walk a lot
# 257  Again, we intend for her to walk, though I thi...
# 485  We live too far to walk, Lack of adequate side...
# 94
# 160  Fear of dangerous driving, Lack of adequate si...
# 45
# 161
# 188
# 491  Fear of dangerous driving, Lack of adequate si...
#
#                                   child_no_bike_reason  \
# 537                        Our own personal preference
# 441  Fear of dangerous driving, Lack of adequate bi...
# 257                         She's just not biking yet.
# 485  My child is too young to bicycle, Fear of dang...
# 94
# 160  Fear of dangerous driving, Lack of adequate bi...
# 45
# 161
# 188
# 491  My child is too young to bicycle, Fear of dang...
#
#                                         no_walk_reason  \
# 537                                  No - I walk a lot
# 441                                  No - I walk a lot
# 257                                  No - I walk a lot
# 485                          I don't have time to walk
# 94                                 My health condition
# 160                                  No - I walk a lot
# 45                          My own personal preference
# 161                          I don't have time to walk
# 188                                  No - I walk a lot
# 491  Fear of dangerous driving, Lack of adequate si...
#
#                                         no_bike_reason  \
# 537                           I do not like to bicycle
# 441  Fear of dangerous driving, Lack of adequate bi...
# 257                              Can't bike with kiddo
# 485          Fear of dangerous driving, Kids are young
# 94                                 My health condition
# 160  Fear of dangerous driving, Lack of adequate bi...
# 45                                     I don't bicycle
# 161  I love to bike - it's all about time - same wi...
# 188                          Fear of dangerous driving
# 491  Fear of dangerous driving, Lack of adequate bi...
#
#                                           drive_reason  \
# 537                       Safety concerns with walking
# 441        No - I do not drive, or prefer not to drive
# 257                         My own personal preference
# 485                     Safety concerns with bicycling
# 94                I don't have time to walk or bicycle
# 160                     Safety concerns with bicycling
# 45                          My own personal preference
# 161               I don't have time to walk or bicycle
# 188                     Safety concerns with bicycling
# 491  Safety concerns with walking, Safety concerns ...
#
#                                           problem_tags  \
# 537                         missing sidewalks, mt airy
# 441  aggressive driving,driver awareness,shoprite,m...
# 257  municipal place,van wyck,cet,gerstein,clevelan...
# 485                 mt airy,speeding,missing sidewalks
# 94
# 160  benedict,cleveland,benedict,truesdale,cet,miss...
# 45                                  sidewalk condition
# 161  cleveland,maple,old post s, old post n,sidewal...
# 188
# 491     grand,129,missing sidewalks,aggressive driving
#
#                                        suggestion_tags
# 537  more signs, sidewalk on mt airy s, more sidewalks
# 441                                     more sidewalks
# 257
# 485
# 94                                       no bike lanes
# 160  parking on one side only,reduce on-street park...
# 45
# 161  more sidewalks, bike lanes,maintain sidewalks,...
# 188
# 491                          more sidewalks,bike lanes

# %% [markdown]
# ## Remove commas from any given answer option so we can later split by comma cleanly

# %%
# loop through all questions that allow more than one answer
for question, answer_list in multiple_answer_options.items():
    # loop through every answer in the answer list for this question
    for answer in answer_list:
        # remove the commas, from each answer, if any
        if ',' in answer:
            # update the answers with a cleaned version
            df[question] = df[question].str.replace(answer, answer.replace(',', '') )
            
    # remove commas from the list of answers in the question/answer dictionary
    multiple_answer_options[question] = [answer.replace(',' , '') for answer in answer_list]

# show the cleaned up answer options
#multiple_answer_options

# %% [markdown]
# ## Tally answers
# Indicate which users selected which answer options, and put any freeform text answers that users entered by clicking the 'other' option in Google Forms into '_other' columns.

# %%
def categorize_answers(response, question, answer_list):    
    """
    Takes a given set of responses to a multi-select question, and puts them into a well-formated Series of dummy values.
    
    @param response A list of the user's responses to this question
    @param question The title of the question (these are codes)
    @param answer_list A list of the answer options that were presented to the user in the Google Form
    """
    
    # set up some lists that we will use to collect responses as dummy values
    indices = [] # will contain the text of the answer option that the user selected
    values = [] # will contain dummy values (1s) for each answer option the user selected, NaNs otherwise.
    
    # skip any nan or blank values
    if str(response) != 'nan' and type(answer_list) != float and type(question) != float and type(response) != float:
        #display(question + " - " + str(response))
        for answer_option in response:
            answer_option = answer_option.strip() # remove any leading/trailing whitespace
            if answer_option in answer_list and question + '_' + answer_option not in indices:
                indices.append(question + '_' + answer_option)
                values.append(1)
            elif answer_option.strip() != '' and question + '_' + 'other' not in indices:
                indices.append(question + '_' + 'other')
                values.append(answer_option)
    
        # put it all into a pandas Series
        response = pd.Series(values,index=indices).fillna(0).astype(str)
        
    return response

# slice up answers by comma and give each its own column
df2 = pd.DataFrame() # build a new dataframe from scratch

# loop through each question/answer item
for question, answer_list in multiple_answer_options.items():
    # get a new dataframe with the questions as indexes and the valuess as dummy values indicating user selections
    d = df[question].str.split(',\s*').apply(categorize_answers, question=question, answer_list=answer_list)
    df2 = df2.append(d) # append this as a row to the new dataframe

# show the new dataframe
df2.sample(n=10) #random sample of rows
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#     child_drive_reason_Lack of available busing where we live  \
# 367                                                NaN
# 61                                                 NaN
# 248                                                NaN
# 488                                                NaN
# 423                                                NaN
# 553                                                NaN
# 247                                                NaN
# 299                                                NaN
# 463                                                NaN
# 94                                                 NaN
#
#     child_drive_reason_My child's health condition  \
# 367                                            NaN
# 61                                             NaN
# 248                                            NaN
# 488                                            NaN
# 423                                            NaN
# 553                                            NaN
# 247                                            NaN
# 299                                            NaN
# 463                                            NaN
# 94                                             NaN
#
#     child_drive_reason_No - we do not drive or prefer not to drive  \
# 367                                                NaN
# 61                                                 NaN
# 248                                                NaN
# 488                                                NaN
# 423                                                NaN
# 553                                                NaN
# 247                                                NaN
# 299                                                NaN
# 463                                                NaN
# 94                                                 NaN
#
#     child_drive_reason_Our own personal preference  \
# 367                                            NaN
# 61                                             NaN
# 248                                            NaN
# 488                                            NaN
# 423                                            NaN
# 553                                            NaN
# 247                                            NaN
# 299                                            NaN
# 463                                            NaN
# 94                                             NaN
#
#     child_drive_reason_Safety concerns with bicycling  \
# 367                                               NaN
# 61                                                NaN
# 248                                               NaN
# 488                                               NaN
# 423                                               NaN
# 553                                               NaN
# 247                                               NaN
# 299                                               NaN
# 463                                               NaN
# 94                                                NaN
#
#     child_drive_reason_Safety concerns with buses  \
# 367                                           NaN
# 61                                            NaN
# 248                                           NaN
# 488                                           NaN
# 423                                           NaN
# 553                                           NaN
# 247                                           NaN
# 299                                           NaN
# 463                                           NaN
# 94                                            NaN
#
#     child_drive_reason_Safety concerns with walking  \
# 367                                             NaN
# 61                                              NaN
# 248                                             NaN
# 488                                             NaN
# 423                                             NaN
# 553                                             NaN
# 247                                             NaN
# 299                                             NaN
# 463                                             NaN
# 94                                              NaN
#
#     child_drive_reason_The bus schedule does not match our schedule  \
# 367                                                NaN
# 61                                                 NaN
# 248                                                NaN
# 488                                                NaN
# 423                                                NaN
# 553                                                NaN
# 247                                                NaN
# 299                                                NaN
# 463                                                NaN
# 94                                                 NaN
#
#     child_drive_reason_other child_no_bike_reason_Fear of dangerous driving  \
# 367                      NaN                                            NaN
# 61                       NaN                                            NaN
# 248                      NaN                                            NaN
# 488                      NaN                                            NaN
# 423                      NaN                                            NaN
# 553                      NaN                                            NaN
# 247                      NaN                                            NaN
# 299                      NaN                                            NaN
# 463                      NaN                                            NaN
# 94                       NaN                                            NaN
#
#      ... suggestion_tags_other suggestion_tags_outlaw cycling  \
# 367  ...                   NaN                            NaN
# 61   ...                   NaN                            NaN
# 248  ...                   NaN                            NaN
# 488  ...                   NaN                            NaN
# 423  ...                   NaN                            NaN
# 553  ...                   NaN                            NaN
# 247  ...                   NaN                            NaN
# 299  ...                   NaN                            NaN
# 463  ...                   NaN                            NaN
# 94   ...                   NaN                            NaN
#
#     suggestion_tags_parking on one side only  \
# 367                                      NaN
# 61                                       NaN
# 248                                      NaN
# 488                                      NaN
# 423                                      NaN
# 553                                      NaN
# 247                                      NaN
# 299                                      NaN
# 463                                      NaN
# 94                                       NaN
#
#     suggestion_tags_reduce on-street parking suggestion_tags_reduce speed  \
# 367                                      NaN                          NaN
# 61                                       NaN                          NaN
# 248                                      NaN                          NaN
# 488                                      NaN                          NaN
# 423                                      NaN                          NaN
# 553                                      NaN                          NaN
# 247                                      NaN                          NaN
# 299                                      NaN                          NaN
# 463                                      NaN                          NaN
# 94                                       NaN                          NaN
#
#     suggestion_tags_sidewalk on mt airy s suggestion_tags_speed bumps  \
# 367                                   NaN                         NaN
# 61                                    NaN                         NaN
# 248                                   NaN                         NaN
# 488                                   NaN                         NaN
# 423                                   NaN                         NaN
# 553                                   NaN                         NaN
# 247                                   NaN                         NaN
# 299                                   NaN                         NaN
# 463                                   NaN                         NaN
# 94                                    NaN                         NaN
#
#     suggestion_tags_speed cameras suggestion_tags_speed indicator signs  \
# 367                           NaN                                   NaN
# 61                            NaN                                   NaN
# 248                           NaN                                   NaN
# 488                           NaN                                   NaN
# 423                           NaN                                   NaN
# 553                           NaN                                   NaN
# 247                           NaN                                   NaN
# 299                           NaN                                   NaN
# 463                           NaN                                   NaN
# 94                            NaN                                   NaN
#
#     suggestion_tags_traffic calming
# 367                             NaN
# 61                              NaN
# 248                             NaN
# 488                             NaN
# 423                             NaN
# 553                             NaN
# 247                             NaN
# 299                             NaN
# 463                             NaN
# 94                              NaN
#
# [10 rows x 130 columns]

# %% [markdown]
# ## Convert values to ints or booleans, where possible
# Most columns contain NaNs or 1s.  NaNs are converted to 0s then to booleans, if desired.  Integer dummy values are perhaps more useful so we can take counts of responses by adding the ints up.  The 'other' columns contain text and are left alone.

# %%
# loop through each column
for col in df2.columns:
    try:
        # try to convert to int
        df2[col] = df2[col].fillna(0).astype(int)#.astype(bool)
    except:
        # if this column contains text, skip...
        continue

# %% [markdown]
# ## Group rows by 'id' so there is one row for each respondent

# %%
# add up all values in each column to get a full set of values or each id
# this loses the 'other' columns, since they are not numeric
df3 = df2.groupby(df2.index).sum()

# show the new grouped data... note that it is missing the 'other' fields... more on that later
df3.sample(n=10) #random sample of rows
# Out:
#      child_drive_reason_Lack of available busing where we live  \
# 475                                                  0
# 275                                                  0
# 312                                                  0
# 124                                                  0
# 522                                                  0
# 344                                                  0
# 410                                                  0
# 551                                                  0
# 483                                                  0
# 253                                                  0
#
#      child_drive_reason_My child's health condition  \
# 475                                               0
# 275                                               0
# 312                                               0
# 124                                               0
# 522                                               0
# 344                                               0
# 410                                               0
# 551                                               0
# 483                                               0
# 253                                               0
#
#      child_drive_reason_No - we do not drive or prefer not to drive  \
# 475                                                  1
# 275                                                  0
# 312                                                  1
# 124                                                  1
# 522                                                  0
# 344                                                  1
# 410                                                  0
# 551                                                  0
# 483                                                  0
# 253                                                  0
#
#      child_drive_reason_Our own personal preference  \
# 475                                               0
# 275                                               0
# 312                                               0
# 124                                               0
# 522                                               0
# 344                                               0
# 410                                               0
# 551                                               0
# 483                                               0
# 253                                               0
#
#      child_drive_reason_Safety concerns with bicycling  \
# 475                                                  0
# 275                                                  0
# 312                                                  0
# 124                                                  0
# 522                                                  0
# 344                                                  0
# 410                                                  0
# 551                                                  0
# 483                                                  0
# 253                                                  0
#
#      child_drive_reason_Safety concerns with buses  \
# 475                                              0
# 275                                              0
# 312                                              0
# 124                                              0
# 522                                              0
# 344                                              0
# 410                                              0
# 551                                              0
# 483                                              0
# 253                                              0
#
#      child_drive_reason_Safety concerns with walking  \
# 475                                                0
# 275                                                0
# 312                                                0
# 124                                                0
# 522                                                0
# 344                                                0
# 410                                                0
# 551                                                0
# 483                                                0
# 253                                                0
#
#      child_drive_reason_The bus schedule does not match our schedule  \
# 475                                                  0
# 275                                                  0
# 312                                                  0
# 124                                                  0
# 522                                                  0
# 344                                                  0
# 410                                                  1
# 551                                                  0
# 483                                                  0
# 253                                                  0
#
#      child_no_bike_reason_Fear of dangerous driving  \
# 475                                               0
# 275                                               0
# 312                                               0
# 124                                               0
# 522                                               0
# 344                                               0
# 410                                               1
# 551                                               0
# 483                                               0
# 253                                               0
#
#      child_no_bike_reason_Hills  ...  suggestion_tags_no bike lanes  \
# 475                           0  ...                              0
# 275                           0  ...                              0
# 312                           0  ...                              0
# 124                           0  ...                              0
# 522                           0  ...                              0
# 344                           0  ...                              0
# 410                           1  ...                              0
# 551                           0  ...                              0
# 483                           0  ...                              0
# 253                           0  ...                              0
#
#      suggestion_tags_outlaw cycling  suggestion_tags_parking on one side only  \
# 475                               0                                         0
# 275                               0                                         0
# 312                               0                                         0
# 124                               0                                         0
# 522                               0                                         0
# 344                               0                                         0
# 410                               0                                         0
# 551                               0                                         0
# 483                               0                                         0
# 253                               0                                         0
#
#      suggestion_tags_reduce on-street parking  suggestion_tags_reduce speed  \
# 475                                         0                             0
# 275                                         0                             0
# 312                                         0                             0
# 124                                         0                             0
# 522                                         0                             0
# 344                                         0                             0
# 410                                         0                             0
# 551                                         0                             0
# 483                                         0                             0
# 253                                         1                             0
#
#      suggestion_tags_sidewalk on mt airy s  suggestion_tags_speed bumps  \
# 475                                      0                            0
# 275                                      0                            0
# 312                                      0                            0
# 124                                      0                            0
# 522                                      0                            0
# 344                                      0                            0
# 410                                      0                            1
# 551                                      0                            0
# 483                                      0                            0
# 253                                      0                            0
#
#      suggestion_tags_speed cameras  suggestion_tags_speed indicator signs  \
# 475                              0                                      0
# 275                              0                                      0
# 312                              0                                      0
# 124                              0                                      0
# 522                              0                                      0
# 344                              0                                      0
# 410                              1                                      0
# 551                              0                                      0
# 483                              0                                      0
# 253                              0                                      0
#
#      suggestion_tags_traffic calming
# 475                                0
# 275                                0
# 312                                0
# 124                                0
# 522                                0
# 344                                0
# 410                                0
# 551                                0
# 483                                0
# 253                                0
#
# [10 rows x 121 columns]

# %% [markdown]
# ## Combine the selected answer options with the 'other' responses users gave

# %%
# loop through all questions
for question, answer_options in multiple_answer_options.items():
    # get a dataframe of just the 'other' answers to this question
    other_df = df2[pd.notnull(df2[question + '_other'])][question + '_other'].to_frame()
    # concatenate those responses to the original dataframe
    df3 = df3.join(other_df)
    
# show the data
df3.sample(n=10) #random sample of rows
# Out:
#      child_drive_reason_Lack of available busing where we live  \
# 83                                                   0
# 271                                                  0
# 308                                                  0
# 215                                                  0
# 473                                                  0
# 475                                                  0
# 66                                                   0
# 291                                                  0
# 130                                                  0
# 299                                                  0
#
#      child_drive_reason_My child's health condition  \
# 83                                                0
# 271                                               0
# 308                                               0
# 215                                               0
# 473                                               0
# 475                                               0
# 66                                                0
# 291                                               0
# 130                                               0
# 299                                               0
#
#      child_drive_reason_No - we do not drive or prefer not to drive  \
# 83                                                   0
# 271                                                  0
# 308                                                  1
# 215                                                  0
# 473                                                  0
# 475                                                  1
# 66                                                   0
# 291                                                  0
# 130                                                  0
# 299                                                  0
#
#      child_drive_reason_Our own personal preference  \
# 83                                                0
# 271                                               0
# 308                                               0
# 215                                               0
# 473                                               0
# 475                                               0
# 66                                                1
# 291                                               0
# 130                                               1
# 299                                               0
#
#      child_drive_reason_Safety concerns with bicycling  \
# 83                                                   1
# 271                                                  0
# 308                                                  0
# 215                                                  0
# 473                                                  0
# 475                                                  0
# 66                                                   0
# 291                                                  0
# 130                                                  0
# 299                                                  0
#
#      child_drive_reason_Safety concerns with buses  \
# 83                                               1
# 271                                              0
# 308                                              0
# 215                                              0
# 473                                              0
# 475                                              0
# 66                                               0
# 291                                              0
# 130                                              0
# 299                                              0
#
#      child_drive_reason_Safety concerns with walking  \
# 83                                                 1
# 271                                                0
# 308                                                0
# 215                                                0
# 473                                                1
# 475                                                0
# 66                                                 0
# 291                                                0
# 130                                                0
# 299                                                0
#
#      child_drive_reason_The bus schedule does not match our schedule  \
# 83                                                   1
# 271                                                  0
# 308                                                  0
# 215                                                  0
# 473                                                  0
# 475                                                  0
# 66                                                   0
# 291                                                  0
# 130                                                  0
# 299                                                  0
#
#      child_no_bike_reason_Fear of dangerous driving  \
# 83                                                1
# 271                                               0
# 308                                               0
# 215                                               0
# 473                                               0
# 475                                               0
# 66                                                0
# 291                                               0
# 130                                               0
# 299                                               0
#
#      child_no_bike_reason_Hills  ...  suggestion_tags_traffic calming  \
# 83                            0  ...                                0
# 271                           0  ...                                0
# 308                           0  ...                                0
# 215                           0  ...                                0
# 473                           0  ...                                0
# 475                           0  ...                                0
# 66                            0  ...                                0
# 291                           0  ...                                0
# 130                           0  ...                                0
# 299                           0  ...                                0
#
#      schools_other  child_drive_reason_other  \
# 83             NaN                       NaN
# 271            NaN                       NaN
# 308            NaN                       NaN
# 215            NaN                       NaN
# 473  Circle school                       NaN
# 475            NaN                       NaN
# 66   St. Augustine                       NaN
# 291            NaN                       NaN
# 130            NaN                       NaN
# 299            NaN                       NaN
#
#               child_no_walk_reason_other  child_no_bike_reason_other  \
# 83                                   NaN                         NaN
# 271                                  NaN                         NaN
# 308                                  NaN                         NaN
# 215                                  NaN                         NaN
# 473                                  NaN                         NaN
# 475  When my child moves from CET to PVC                         NaN
# 66                                   NaN                         NaN
# 291                                  NaN                         NaN
# 130                                  NaN                         NaN
# 299                                  NaN                         NaN
#
#      no_walk_reason_other                               no_bike_reason_other  \
# 83                    NaN                                      Hilly terrain
# 271                   NaN                                     Don’t know how
# 308                   NaN                                                NaN
# 215                   NaN                                                NaN
# 473                   NaN                                                NaN
# 475                   NaN                                                NaN
# 66                    NaN                                                NaN
# 291                   NaN                                                NaN
# 130                Timing  Timing I am in a rush and I have a nice bike t...
# 299                   NaN                                                NaN
#
#                                     drive_reason_other  problem_tags_other  \
# 83                                                 NaN          dobbs park
# 271                              Distance from my airy                 NaN
# 308                                                NaN                 NaN
# 215                                                NaN                 NaN
# 473                                                NaN                 NaN
# 475  Trasnport of STUFF would #1 reason. i.e. groce...                 NaN
# 66                                                 NaN               speed
# 291                                                NaN                 NaN
# 130                       Timing and usually in a rush               taxes
# 299                                                NaN                 NaN
#
#               suggestion_tags_other
# 83                              NaN
# 271                             NaN
# 308              raise speed limits
# 215                             NaN
# 473               lower speed limit
# 475                             NaN
# 66   stop sign on oprn at stevenson
# 291                             NaN
# 130                     lower taxes
# 299                             NaN
#
# [10 rows x 130 columns]

# %% [markdown]
# ## Order the columns alphabetically
# So it looks a bit more orderly

# %%
column_names = df3.columns.sort_values()
df3 = df3[column_names]
df3.sample(n=10) #random sample of rows
# Out:
#      child_drive_reason_Lack of available busing where we live  \
# 474                                                  0
# 268                                                  0
# 321                                                  0
# 407                                                  0
# 468                                                  0
# 234                                                  0
# 334                                                  0
# 51                                                   0
# 27                                                   0
# 102                                                  0
#
#      child_drive_reason_My child's health condition  \
# 474                                               0
# 268                                               0
# 321                                               0
# 407                                               0
# 468                                               0
# 234                                               0
# 334                                               0
# 51                                                0
# 27                                                0
# 102                                               0
#
#      child_drive_reason_No - we do not drive or prefer not to drive  \
# 474                                                  0
# 268                                                  0
# 321                                                  0
# 407                                                  0
# 468                                                  0
# 234                                                  0
# 334                                                  0
# 51                                                   0
# 27                                                   1
# 102                                                  0
#
#      child_drive_reason_Our own personal preference  \
# 474                                               0
# 268                                               0
# 321                                               0
# 407                                               1
# 468                                               0
# 234                                               0
# 334                                               0
# 51                                                0
# 27                                                0
# 102                                               0
#
#      child_drive_reason_Safety concerns with bicycling  \
# 474                                                  0
# 268                                                  0
# 321                                                  0
# 407                                                  0
# 468                                                  0
# 234                                                  0
# 334                                                  0
# 51                                                   0
# 27                                                   0
# 102                                                  0
#
#      child_drive_reason_Safety concerns with buses  \
# 474                                              0
# 268                                              0
# 321                                              0
# 407                                              0
# 468                                              0
# 234                                              0
# 334                                              0
# 51                                               0
# 27                                               0
# 102                                              0
#
#      child_drive_reason_Safety concerns with walking  \
# 474                                                0
# 268                                                0
# 321                                                0
# 407                                                0
# 468                                                0
# 234                                                0
# 334                                                0
# 51                                                 0
# 27                                                 0
# 102                                                0
#
#      child_drive_reason_The bus schedule does not match our schedule  \
# 474                                                  0
# 268                                                  0
# 321                                                  0
# 407                                                  0
# 468                                                  0
# 234                                                  0
# 334                                                  0
# 51                                                   0
# 27                                                   0
# 102                                                  0
#
#     child_drive_reason_other  child_no_bike_reason_Fear of dangerous driving  \
# 474                      NaN                                               0
# 268                      NaN                                               0
# 321                      NaN                                               0
# 407                      NaN                                               0
# 468                      NaN                                               0
# 234                      NaN                                               0
# 334                      NaN                                               0
# 51                       NaN                                               0
# 27                       NaN                                               1
# 102                      NaN                                               0
#
#      ...         suggestion_tags_other  suggestion_tags_outlaw cycling  \
# 474  ...                           NaN                               0
# 268  ...       retrain crossing guards                               0
# 321  ...                           NaN                               0
# 407  ...                           NaN                               0
# 468  ...                           NaN                               0
# 234  ...                           NaN                               0
# 334  ...                           NaN                               0
# 51   ...  allow scooters in bike lanes                               0
# 27   ...                           NaN                               0
# 102  ...                           NaN                               1
#
#      suggestion_tags_parking on one side only  \
# 474                                         0
# 268                                         0
# 321                                         0
# 407                                         0
# 468                                         0
# 234                                         0
# 334                                         0
# 51                                          0
# 27                                          0
# 102                                         0
#
#      suggestion_tags_reduce on-street parking  suggestion_tags_reduce speed  \
# 474                                         0                             0
# 268                                         0                             0
# 321                                         0                             0
# 407                                         0                             0
# 468                                         0                             0
# 234                                         0                             0
# 334                                         0                             0
# 51                                          0                             0
# 27                                          0                             0
# 102                                         0                             0
#
#      suggestion_tags_sidewalk on mt airy s  suggestion_tags_speed bumps  \
# 474                                      0                            0
# 268                                      0                            0
# 321                                      0                            0
# 407                                      0                            0
# 468                                      0                            0
# 234                                      0                            0
# 334                                      0                            0
# 51                                       0                            0
# 27                                       0                            0
# 102                                      0                            0
#
#      suggestion_tags_speed cameras  suggestion_tags_speed indicator signs  \
# 474                              1                                      0
# 268                              0                                      0
# 321                              0                                      0
# 407                              0                                      0
# 468                              0                                      0
# 234                              0                                      0
# 334                              0                                      0
# 51                               0                                      0
# 27                               0                                      0
# 102                              0                                      0
#
#     suggestion_tags_traffic calming
# 474                               0
# 268                               0
# 321                               0
# 407                               0
# 468                               0
# 234                               0
# 334                               0
# 51                                0
# 27                                0
# 102                               0
#
# [10 rows x 130 columns]

# %% [markdown]
# ## Merge with remaining data

# %%
# load up the original data from scratch again
df = pd.read_csv('responses_scrubbed_tagged.csv', index_col=None, parse_dates=['date'])

# merge the new columns with the old dataframe based on the indexes of each row
df_complete = pd.merge(df, df3, right_index=True, left_index=True)

df_complete.sample(n=10) #random sample of rows
# Out:
#                    date         neighborhood               demographic  \
# 471 2019-07-10 22:07:31        Upper Village  Adult without school kid
# 478 2019-07-11 16:48:19  Old Post Road North     Adult with school kid
# 131 2019-07-03 17:07:37           Mount Airy                    Senior
# 124 2019-07-03 16:55:00               Harmon     Adult with school kid
# 421 2019-07-09 12:39:05        Upper Village     Adult with school kid
# 219 2019-07-03 21:53:12  Old Post Road North     Adult with school kid
# 114 2019-07-03 16:37:06        Upper Village     Adult with school kid
# 176 2019-07-03 19:02:48          Sunset Park  Adult without school kid
# 20  2019-07-03 15:37:33  Old Post Road North  Adult without school kid
# 227 2019-07-03 22:58:41          Sunset Park     Adult with school kid
#
#                      child_bus_freq  \
# 471                             NaN
# 478  Every day, or almost every day
# 131                             NaN
# 124  Every day, or almost every day
# 421  Every day, or almost every day
# 219  Every day, or almost every day
# 114                 Rarely or never
# 176                             NaN
# 20                              NaN
# 227  Every day, or almost every day
#
#                                  child_bike_freq    child_driven_freq  \
# 471                                          NaN                  NaN
# 478          Rarely or never - for other reasons      Once in a while
# 131                                          NaN                  NaN
# 124          Rarely or never - for other reasons      Rarely or never
# 421  Rarely or never - my children are too young      Once in a while
# 219  Rarely or never - my children are too young      Once in a while
# 114          Rarely or never - for other reasons  Once every few days
# 176                                          NaN                  NaN
# 20                                           NaN                  NaN
# 227  Rarely or never - my children are too young      Rarely or never
#
#                                 child_drive_freq  \
# 471                                          NaN
# 478  Rarely or never - my children are too young
# 131                                          NaN
# 124          Rarely or never - for other reasons
# 421  Rarely or never - my children are too young
# 219  Rarely or never - my children are too young
# 114  Rarely or never - my children are too young
# 176                                          NaN
# 20                                           NaN
# 227  Rarely or never - my children are too young
#
#                                  child_walk_freq  \
# 471                                          NaN
# 478          Rarely or never - for other reasons
# 131                                          NaN
# 124          Rarely or never - for other reasons
# 421  Rarely or never - my children are too young
# 219  Rarely or never - my children are too young
# 114               Every day, or almost every day
# 176                                          NaN
# 20                                           NaN
# 227  Rarely or never - my children are too young
#
#                           walk_freq                       bike_freq  ...  \
# 471  Every day, or almost every day                 Once in a while  ...
# 478             Once every few days                 Rarely or never  ...
# 131             Once every few days                 Rarely or never  ...
# 124                 Rarely or never                 Rarely or never  ...
# 421  Every day, or almost every day  Every day, or almost every day  ...
# 219             Once every few days                 Rarely or never  ...
# 114  Every day, or almost every day                 Once in a while  ...
# 176                 Once in a while                 Once in a while  ...
# 20                  Once in a while                 Rarely or never  ...
# 227                 Once in a while                 Rarely or never  ...
#
#     suggestion_tags_other suggestion_tags_outlaw cycling  \
# 471                   NaN                              0
# 478                   NaN                              0
# 131                   NaN                              0
# 124                   NaN                              0
# 421                   NaN                              0
# 219                   NaN                              0
# 114                   NaN                              0
# 176                   NaN                              0
# 20                    NaN                              0
# 227                   NaN                              0
#
#     suggestion_tags_parking on one side only  \
# 471                                        0
# 478                                        0
# 131                                        0
# 124                                        0
# 421                                        0
# 219                                        0
# 114                                        0
# 176                                        0
# 20                                         0
# 227                                        0
#
#     suggestion_tags_reduce on-street parking suggestion_tags_reduce speed  \
# 471                                        0                            1
# 478                                        0                            0
# 131                                        0                            0
# 124                                        0                            0
# 421                                        0                            0
# 219                                        0                            0
# 114                                        0                            0
# 176                                        0                            0
# 20                                         0                            0
# 227                                        0                            0
#
#     suggestion_tags_sidewalk on mt airy s suggestion_tags_speed bumps  \
# 471                                     0                           0
# 478                                     0                           0
# 131                                     0                           0
# 124                                     0                           0
# 421                                     0                           0
# 219                                     0                           0
# 114                                     0                           0
# 176                                     0                           0
# 20                                      0                           0
# 227                                     0                           0
#
#     suggestion_tags_speed cameras suggestion_tags_speed indicator signs  \
# 471                             0                                     0
# 478                             0                                     0
# 131                             0                                     0
# 124                             0                                     0
# 421                             0                                     0
# 219                             0                                     0
# 114                             0                                     0
# 176                             0                                     0
# 20                              0                                     0
# 227                             0                                     0
#
#     suggestion_tags_traffic calming
# 471                               0
# 478                               0
# 131                               0
# 124                               0
# 421                               0
# 219                               0
# 114                               0
# 176                               0
# 20                                0
# 227                               0
#
# [10 rows x 210 columns]

# %% [markdown]
# ## Group together some related sets of tags from the free text responses
# There were several tags given for complaints about speeding, sidewalks, crosswalks, etc.... Make aggregate columns to make these things easier to search for.

# %%
def aggregate_tags(row, related_tags):
    """
    This method looks for a dummy value in a set of related fields.
    Returns 1 if found, 0 others.
    """
    # loop through each tag in the group
    for tag in related_tags:
        # if we find a one, then we're done
        if row[tag] == 1:
            return 1
    # otherwise, we did not find what we were looking for
    return 0

# make some new aggregate columns around topics that are otherwise represented across several fields

# a bunch of tags all related to concerns with drivers' behavior and speed
related_tags = ['problem_tags_driver awareness', 'problem_tags_aggressive driving', 'problem_tags_speeding', 'suggestion_tags_reduce speed', 'suggestion_tags_enforce speed', 'suggestion_tags_speed bumps', 'suggestion_tags_speed cameras', 'suggestion_tags_speed indicator signs', 'suggestion_tags_traffic calming']
df_complete['concerns_with_drivers'] = df_complete.apply (lambda row: aggregate_tags(row, related_tags), axis=1)

# a bunch of tags all related to concerns with sidewalks
related_tags = ['problem_tags_missing sidewalks', 'problem_tags_sidewalk condition', 'suggestion_tags_more sidewalks', 'suggestion_tags_maintain sidewalks']
df_complete['concerns_with_sidewalks'] = df_complete.apply (lambda row: aggregate_tags(row, related_tags), axis=1)

# a bunch of tags all related to concerns with crosswalks
related_tags = ['problem_tags_missing crosswalks', 'suggestion_tags_more crosswalks', 'suggestion_tags_maintain crosswalks', 'suggestion_tags_enforce crosswalks']
df_complete['concerns_with_crosswalks'] = df_complete.apply (lambda row: aggregate_tags(row, related_tags), axis=1)

# %% [markdown]
# ## Save to new CSV file

# %%
df_complete.to_csv('responses_complete.csv', index=False)

# %% [markdown]
# ## Done!
